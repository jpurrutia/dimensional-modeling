# %% [markdown]
# # Dimensional Modeling in Python

# %% [markdown]
# ## Import Dependencies

# %%
import pandas as pd
import psycopg2
import psycopg2.extras as extras
from db import local_dbc, df_to_table
import os

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 100)
pd.set_option('display.width', 1000)

# %% [markdown]
# ## Reading CSV File

# %%
df = pd.read_csv('disclosure_data.csv', encoding='utf-8')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (6,16,19,85,122) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ## Data Quality Check for Nulls

# %%
percent_missing = df.isnull().sum() * 100 / len(df)

missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percent_missing': percent_missing})

percent_missing.head(100)
# Out:
# CASE_NUMBER                          0.000000
# CASE_STATUS                          0.000000
# RECEIVED_DATE                        0.000000
# DECISION_DATE                        0.000000
# REFILE                               0.000000
# ORIG_FILE_DATE                      99.898957
# PREVIOUS_SWA_CASE_NUMBER_STATE      99.896829
# SCHD_A_SHEEPHERDER                   0.005318
# EMPLOYER_NAME                        0.001064
# EMPLOYER_ADDRESS_1                   0.006382
# EMPLOYER_ADDRESS_2                  64.691179
# EMPLOYER_CITY                        0.001064
# EMPLOYER_STATE_PROVINCE              0.002127
# EMPLOYER_COUNTRY                     0.025527
# EMPLOYER_POSTAL_CODE                 0.004254
# EMPLOYER_PHONE                       0.002127
# EMPLOYER_PHONE_EXT                  92.026080
# EMPLOYER_NUM_EMPLOYEES               0.015954
# EMPLOYER_YEAR_COMMENCED_BUSINESS     0.044672
# NAICS_CODE                           0.086153
# FW_OWNERSHIP_INTEREST                0.007445
# EMP_CONTACT_NAME                     0.000000
# EMP_CONTACT_ADDRESS_1                0.007445
# EMP_CONTACT_ADDRESS_2               61.048299
# EMP_CONTACT_CITY                     0.002127
# EMP_CONTACT_STATE_PROVINCE           0.004254
# EMP_CONTACT_COUNTRY                  0.015954
# EMP_CONTACT_POSTAL_CODE              0.009573
# EMP_CONTACT_PHONE                    0.000000
# EMP_CONTACT_EMAIL                    0.040417
# AGENT_ATTORNEY_NAME                  0.000000
# AGENT_ATTORNEY_FIRM_NAME             8.207915
# AGENT_ATTORNEY_PHONE                 6.248737
# AGENT_ATTORNEY_PHONE_EXT            97.149512
# AGENT_ATTORNEY_ADDRESS_1             6.238101
# AGENT_ATTORNEY_ADDRESS_2            36.202257
# AGENT_ATTORNEY_CITY                  6.242355
# AGENT_ATTORNEY_STATE_PROVINCE        7.382550
# AGENT_ATTORNEY_COUNTRY               6.246610
# AGENT_ATTORNEY_POSTAL_CODE           6.309363
# AGENT_ATTORNEY_EMAIL                 6.274264
# PW_TRACK_NUMBER                      0.263776
# PW_SOC_CODE                          0.072326
# PW_SOC_TITLE                         0.015954
# PW_SKILL_LEVEL                       5.776492
# PW_WAGE                              0.017018
# PW_UNIT_OF_PAY                       0.017018
# PW_WAGE_SOURCE                       0.025527
# PW_SOURCE_NAME_OTHER                95.436029
# PW_DETERMINATION_DATE                0.063817
# PW_EXPIRATION_DATE                   0.069135
# WAGE_OFFER_FROM                      0.010636
# WAGE_OFFER_TO                       62.339527
# WAGE_OFFER_UNIT_OF_PAY               0.010636
# WORKSITE_ADDRESS_1                   0.012763
# WORKSITE_ADDRESS_2                  63.092566
# WORKSITE_CITY                        0.007445
# WORKSITE_STATE                       0.007445
# WORKSITE_POSTAL_CODE                 0.010636
# JOB_TITLE                            0.017018
# MINIMUM_EDUCATION                    0.008509
# JOB_EDUCATION_MIN_OTHER             97.522841
# MAJOR_FIELD_OF_STUDY                15.183101
# REQUIRED_TRAINING                    0.004254
# REQUIRED_TRAINING_MONTHS            98.767270
# REQUIRED_FIELD_OF_TRAINING          98.764080
# REQUIRED_EXPERIENCE                  0.004254
# REQUIRED_EXPERIENCE_MONTHS          44.621832
# ACCEPT_ALT_FIELD_OF_STUDY            0.006382
# ACCEPT_ALT_MAJOR_FLD_OF_STUDY       58.570076
# ACCEPT_ALT_COMBO                     0.009573
# ACCEPT_ALT_COMBO_EDUCATION          71.520650
# ACCEPT_ALT_COMBO_ED_OTHER           98.088684
# ACCEPT_ALT_COMBO_EDUCATION_YRS      71.708910
# ACCEPT_FOREIGN_EDUCATION             0.013827
# ACCEPT_ALT_OCCUPATION                0.004254
# ACCEPT_ALT_OCCUPATION_MONTHS        32.159457
# ACCEPT_ALT_JOB_TITLE                32.133930
# JOB_OPP_REQUIREMENTS_NORMAL          0.001064
# FOREIGN_LANGUAGE_REQUIRED            0.001064
# SPECIFIC_SKILLS                      8.381285
# COMBINATION_OCCUPATION               0.001064
# OFFERED_TO_APPL_FOREIGN_WORKER       0.002127
# FOREIGN_WORKER_LIVE_ON_PREM          0.002127
# FOREIGN_WORKER_LIVE_IN_DOM_SER       0.002127
# FOREIGN_WORKER_LIVE_IN_DOM_CNT      99.937247
# PROFESSIONAL_OCCUPATION              0.002127
# APP_FOR_COLLEGE_U_TEACHER            0.011700
# COMPETITIVE_PROCESS                 97.442006
# BASIC_RECRUITMENT_PROCESS           97.443070
# TEACHER_SELECT_DATE                 97.795127
# TEACHER_PUB_JOURNAL_NAME            97.789808
# ADD_RECRUIT_INFORMATION             97.837671
# SWA_JOB_ORDER_START_DATE             2.267627
# SWA_JOB_ORDER_END_DATE               2.277199
# SUNDAY_EDITION_NEWSPAPER             2.244227
# FIRST_NEWSPAPER_NAME                 2.272945
# FIRST_ADVERTISEMENT_START_DATE       2.269754
# SECOND_NEWSPAPER_AD_NAME             2.291026
# SECOND_ADVERTISEMENT_TYPE            2.276136
# dtype: float64

# %% [markdown]
# ## Cleaning Column Names

# %%
df.columns = [col.lower() for col in df.columns]

# %% [markdown]
# ## Subsetting DataFrame

# %%
df = df[['case_number',
'case_status',
'received_date',
'decision_date',
'refile',
'orig_file_date',
'previous_swa_case_number_state',
'schd_a_sheepherder',
'employer_name',
'employer_address_1',
'employer_address_2',
'employer_city',
'employer_state_province',
'employer_country',
'employer_postal_code',
'employer_phone',
'employer_phone_ext',
'employer_num_employees',
'employer_year_commenced_business',
'naics_code',
'fw_ownership_interest',
'emp_contact_name',
'emp_contact_address_1',
'emp_contact_address_2',
'emp_contact_city',
'emp_contact_state_province',
'emp_contact_country',
'emp_contact_postal_code',
'emp_contact_phone',
'emp_contact_email',
'agent_attorney_name',
'agent_attorney_firm_name',
'agent_attorney_phone',
'agent_attorney_phone_ext',
'agent_attorney_address_1',
'agent_attorney_address_2',
'agent_attorney_city',
'agent_attorney_state_province',
'agent_attorney_country',
'agent_attorney_postal_code',
'agent_attorney_email']]

# %% [markdown]
# ## Create Dimension Tables

# %%
### testing bulk insert function

# %%
# load csv into df
df = pd.read_csv('disclosure_data.csv', encoding='utf-8')

# connect to db and set cursor
db = local_dbc()
cur = db.cursor()

# set table/columns vars
table = 'disclosure_test.disclosure_test_fact'
cols = ','.join(list(df.columns))

# convert rows into tuples
tuples = [tuple(x) for x in df.to_numpy()]

# set sql query for insert statement
sql = "INSERT INTO %s(%s) VALUES %%s" % (table, cols)

# bulk insert values into table
extras.execute_values(cur, sql, tuples)

# commit changes
db.commit()

# %%
tuples
# Out:
# [('A-09245-62715',
#   'Denied',
#   '9/3/09',
#   '4/30/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'SATURN ENTERPRISES INC',
#   '2340 N WASHTENAW AVE',
#   nan,
#   'CHICAGO',
#   'ILLINOIS',
#   'UNITED STATES OF AMERICA',
#   '60647',
#   '7732769550',
#   nan,
#   2.0,
#   1998.0,
#   '23611',
#   'N',
#   'zygmunt f oparowski',
#   '2340 n washtenaw ave',
#   nan,
#   'chicago',
#   'ILLINOIS',
#   'UNITED STATES OF AMERICA',
#   '60647',
#   '7732769550',
#   'saturn_enterprises@yahoo.com',
#   'Christopher E Kurczaba',
#   'Kurczaba Law Offices',
#   '7737740011',
#   nan,
#   '6219 N Milwaukee Ave',
#   nan,
#   'Chicago',
#   'ILLINOIS',
#   'UNITED STATES OF AMERICA',
#   '60646',
#   'kurczabalaw@sbcglobal.net'),
#  ('A-10070-89932',
#   'Certified',
#   '10/22/19',
#   '9/4/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'SUNRAY ENTERPRISE INC.',
#   '3621 VININGS SLOPE SUITE#4310',
#   nan,
#   'ATLANTA',
#   'GEORGIA',
#   'UNITED STATES OF AMERICA',
#   '30339',
#   '678-584-1312',
#   '224',
#   45.0,
#   2002.0,
#   '541512',
#   'N',
#   'Sunitha  Shivaram',
#   '3621 Vinings Slope Suite#4310',
#   nan,
#   'Atlanta',
#   'GEORGIA',
#   'UNITED STATES OF AMERICA',
#   '30339',
#   '678-584-1312 224',
#   'sunithas@sunraycorp.com',
#   'James E McLaughlin III',
#   'Murthy Law Firm',
#   '4103565440',
#   nan,
#   '10451 Mill Run Circle',
#   'Suite 100',
#   'Owings Mills',
#   'MARYLAND',
#   'UNITED STATES OF AMERICA',
#   '21117',
#   'perm@murthy.com'),
#  ('A-10119-96737',
#   'Certified-Expired',
#   '3/29/10',
#   '10/18/19',
#   'Y',
#   '9/15/00',
#   'MARYLAND',
#   'N',
#   'FIL PARONG',
#   '13528 JAMIESON PL',
#   nan,
#   'GERMANTOWN',
#   'MARYLAND',
#   'UNITED STATES OF AMERICA',
#   '20874',
#   '301-515-8079',
#   nan,
#   0.0,
#   2009.0,
#   '531110',
#   'N',
#   'FIL  PARONG',
#   '13528 JAMIESON PL',
#   nan,
#   'GERMANTOWN',
#   'MARYLAND',
#   'UNITED STATES OF AMERICA',
#   '20874',
#   '(301) 515-8079 ',
#   nan,
#   'WINSTON W TSAI',
#   'WINSTON TSAI, ESQ.',
#   '(301) 320- 1888',
#   nan,
#   '6202 WINSTON DRIVE',
#   nan,
#   'BETHESDA',
#   'MARYLAND',
#   'UNITED STATES OF AMERICA',
#   '20817',
#   'WINSTONTSAI@AOL.COM'),
#  ('A-10225-13679',
#   'Denied',
#   '8/10/10',
#   '4/30/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'GLENNS PLUMBING SERVICES',
#   '854 CUSTER STREET',
#   nan,
#   'N. VALLEY STREAM',
#   'NEW YORK',
#   'UNITED STATES OF AMERICA',
#   '11580',
#   '516-561-3692',
#   nan,
#   3.0,
#   2002.0,
#   nan,
#   'N',
#   'DAVID  GLENN',
#   '854 CUSTER STREET',
#   nan,
#   'N. VALLEY STREAM',
#   'NEW YORK',
#   'UNITED STATES OF AMERICA',
#   '11580',
#   '516-561-3692 ',
#   nan,
#   'DANIEL J SULLIVAN',
#   'DANIEL J. SULLIVAN, ESQ.',
#   '631-732-3516',
#   nan,
#   '815 HORSEBLOCK ROAD',
#   nan,
#   'FARMINGVILLE',
#   'NEW YORK',
#   'UNITED STATES OF AMERICA',
#   '11738',
#   'GWG8@AOL.COM'),
#  ('A-10334-34885',
#   'Certified',
#   '12/2/10',
#   '8/24/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'ASTIR IT SOLUTIONS, INC',
#   '50 CRAGWOOD ROAD, SUITE 219',
#   nan,
#   'SOUTH PLAINFIELD',
#   'NEW JERSEY',
#   'UNITED STATES OF AMERICA',
#   '07080',
#   '908.279.8670',
#   '704',
#   90.0,
#   2001.0,
#   '541511',
#   'N',
#   'Kishore  Ganji',
#   '50 CRAGWOOD ROAD, SUITE 219',
#   nan,
#   'SOUTH PLAINFIELD',
#   'NEW JERSEY New Jersey',
#   'UNITED STATES OF AMERICA',
#   '07080',
#   '908.279.8670 703',
#   'kishoreg@astirit.com',
#   'Kavitha  Ramasami',
#   'Law Offices of Kavitha Ramasami',
#   '7323939557',
#   nan,
#   '450 Seventh Avenue, Suite 2600',
#   nan,
#   'New York',
#   'NEW YORK',
#   'UNITED STATES OF AMERICA',
#   '10123',
#   'kavitha@usimmigrationesq.com'),
#  ('A-11033-51337',
#   'Denied',
#   '1/31/11',
#   '8/11/20',
#   'Y',
#   '6/23/04',
#   'D-05194-21256',
#   'N',
#   'DURANT HARVESTING, INC.',
#   '621 SOUTH SMITH STREET',
#   'MAIL TO P.O. BOX 1370  SANTA MARIA, CA 93456',
#   'SANTA MARIA',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '93458',
#   '(805) 349-2820',
#   nan,
#   250.0,
#   2001.0,
#   '115113',
#   'N',
#   'TOM  DURANT',
#   '621 SOUTH SMITH STREET',
#   'MAIL TO P.O. BOX 1370 SANTA MARIA, CA 93456',
#   'SANTA MARIA',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '93458',
#   '(805) 349-2820 ',
#   nan,
#   'KEVIN M TRACY',
#   'LAW OFFICE OF KEVIN M. TRACY   NORTH COUNTY LEGALIZATION SERVICES, INC',
#   '(858) 481-0822',
#   nan,
#   '2010 JIMMY DURANTE BLVD., SUITE 126',
#   nan,
#   'DEL MAR',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '92014',
#   'SJEANNETTE@NCLS.NET'),
#  ('A-11033-51540',
#   'Certified',
#   '2/3/11',
#   '5/28/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'SKILLNET SOLUTIONS INC.',
#   '1901 SOUTH BASCOM AVENUE',
#   'SUITE 600',
#   'CAMPBELL',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '95008',
#   '408-523-6225',
#   nan,
#   29.0,
#   1996.0,
#   '519190',
#   'N',
#   'Jack  Grover',
#   '1151 Sonora Court',
#   'Suite 2',
#   'Sunnyvale',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '94086',
#   '408-523-6225 ',
#   'jack@skillnetinc.com',
#   'Sonal  Kinger',
#   'Baker Law Corporation',
#   '(408) 971-0282',
#   nan,
#   '111 North Market Street,',
#   'Suite 300',
#   'San Jose',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '95113',
#   'sonal.kinger@bakerlawcorp.com'),
#  ('A-11074-62984',
#   'Denied',
#   '3/10/11',
#   '6/17/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'R    L  CONSTRUCTION,  INC.',
#   '904  NEPPERHAN  AVENUE',
#   nan,
#   'YONKERS',
#   'NEW YORK',
#   'UNITED STATES OF AMERICA',
#   '10703',
#   '(914) 423-2400',
#   nan,
#   43.0,
#   1987.0,
#   '236115',
#   'N',
#   "RITA  O ' SULLIVAN",
#   '904  NEPPERHAN  AVENUE',
#   nan,
#   'YONKERS',
#   'NEW YORK',
#   'UNITED STATES OF AMERICA',
#   '10703',
#   '(914) 423-2400 ',
#   'ROSULLIVAN@RLCON.COM',
#   'VERNON L DUTTON',
#   'NON  ATTORNEY',
#   '(718) 356-0592',
#   nan,
#   '130  NANCY  LANE',
#   nan,
#   'STATEN  ISLAND',
#   'NEW YORK',
#   'UNITED STATES OF AMERICA',
#   '10307',
#   'MRDUTTON@VERIZON.NET'),
#  ('A-11138-79166',
#   'Denied',
#   '5/19/11',
#   '6/25/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'SHIRE HUMAN GENETIC THERAPIES SHGT INC',
#   '300 SHIRE WAY',
#   nan,
#   'LEXINGTON',
#   'MASSACHUSETTS',
#   'UNITED STATES OF AMERICA',
#   '02421',
#   '781-482-0599',
#   nan,
#   3682.0,
#   1994.0,
#   '541710',
#   'N',
#   'Brett  Jeffries',
#   '700 Main Street',
#   nan,
#   'Cambridge',
#   'MASSACHUSETTS',
#   'UNITED STATES OF AMERICA',
#   '02139',
#   '484-595-5305 ',
#   'bjeffries@shire.com',
#   'Jill K Soubel',
#   'The Rudnick Spector Firm PC',
#   '(215) 690-5100',
#   nan,
#   '1608 Walnut Street, Suite 1700',
#   nan,
#   'Philadelphia',
#   'PENNSYLVANIA',
#   'UNITED STATES OF AMERICA',
#   '19103',
#   'jsoubel@rudnickspector.com'),
#  ('A-11154-83015',
#   'Denied',
#   '6/7/11',
#   '7/16/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'LA TRATTORIA, LLC',
#   '915 15TH STREET, NW',
#   nan,
#   'WASHINGTON',
#   'DISTRICT OF COLUMBIA',
#   'UNITED STATES OF AMERICA',
#   '20005',
#   '202-628-2220',
#   nan,
#   10.0,
#   2009.0,
#   '722110',
#   'N',
#   'Martin  Lackovic',
#   '915 15th Street, NW',
#   nan,
#   'Washington',
#   'DISTRICT OF COLUMBIA',
#   'UNITED STATES OF AMERICA',
#   '20005',
#   '202-628-2220 ',
#   'mar10j@earthlink.net',
#   'Paul S Haar',
#   'Law Offices of Paul S Haar',
#   '202-862-4328',
#   nan,
#   '1150 Connecticut Avenue NW',
#   'Suite 900',
#   'Washington',
#   'DISTRICT OF COLUMBIA',
#   'UNITED STATES OF AMERICA',
#   '20036',
#   'paulhaar@aol.com'),
#  ('A-11158-83590',
#   'Denied',
#   '6/16/11',
#   '8/26/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'PELICAN EDUCATIONAL FOUNDATION',
#   '7600 BOONE AVENUE',
#   nan,
#   'BATON ROUGE',
#   'LOUISIANA',
#   'UNITED STATES OF AMERICA',
#   '70808',
#   '225-766-8111',
#   nan,
#   55.0,
#   2005.0,
#   '611110',
#   'N',
#   'Tevfik  Eski',
#   '7600 Boone Ave,',
#   nan,
#   'Baton Rouge',
#   'LOUISIANA',
#   'UNITED STATES OF AMERICA',
#   '70808',
#   '1-225-766-8111 208',
#   'hr@kenilworthst.org',
#   'Garrett M White',
#   'Law Office of Garrett White',
#   '7136215297',
#   nan,
#   '4151 Southwest Freeway',
#   'Suite 600',
#   'Houston',
#   'TEXAS',
#   'UNITED STATES OF AMERICA',
#   '77027',
#   'gwhitevisa@hotmail.com'),
#  ('A-11158-83757',
#   'Certified-Expired',
#   '8/15/19',
#   '11/5/19',
#   'N',
#   nan,
#   nan,
#   'N',
#   'OMRON AUTOMOTIVE ELECTRONICS, INC.',
#   '3709 OHIO AVENUE',
#   nan,
#   'ST. CHARLES',
#   'ILLINOIS',
#   'UNITED STATES OF AMERICA',
#   '60174',
#   '630-443-6800',
#   '208',
#   718.0,
#   1992.0,
#   '334419',
#   'N',
#   'Jennifer  Dobbs',
#   '3709 OHIO AVENUE',
#   nan,
#   'ST. CHARLES',
#   'ILLINOIS',
#   'UNITED STATES OF AMERICA',
#   '60174',
#   '630-443-7610 208',
#   'jennifer.dobbs@omron.com',
#   'Fazila  Vaid',
#   'Masuda, Funai, Eifert  Mitchell, Ltd.',
#   '847.734.8811',
#   nan,
#   '200 N. Martingale',
#   'Suite 800',
#   'Schaumburg',
#   'ILLINOIS',
#   'UNITED STATES OF AMERICA',
#   '60173-5485',
#   'fvaid@masudafunai.com'),
#  ('A-11178-88571',
#   'Denied',
#   '6/27/11',
#   '8/24/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'AUTOMATED PARKING TECHNOLOGIES, LLC',
#   '500 W. 18TH STREET',
#   'SUITE 301',
#   'CHICAGO',
#   'ILLINOIS',
#   'UNITED STATES OF AMERICA',
#   '60616',
#   '3129429570',
#   '207',
#   10.0,
#   2001.0,
#   '561621',
#   'N',
#   'Eric J Risch',
#   '500 W. 18th Street',
#   'Suite 301',
#   'Chicago',
#   'ILLINOIS',
#   'UNITED STATES OF AMERICA',
#   '60616',
#   '3129429570 207',
#   'ericr@aptchicago.com',
#   'Annette E Gustafsson Guenther',
#   'Law Offices A.E. Gustafsson, P.C.',
#   '6303575700',
#   nan,
#   '200 East 5th Avenue',
#   'Suite 124',
#   'Chicago',
#   'ILLINOIS',
#   'UNITED STATES OF AMERICA',
#   '60563',
#   'annette@lawgustafsson.com'),
#  ('A-11187-90575',
#   'Certified-Expired',
#   '8/31/11',
#   '11/1/19',
#   'N',
#   nan,
#   nan,
#   'N',
#   'ITECH US INC.',
#   '20 KIMBALL AVENUE',
#   'SUITE 303 NORTH',
#   'SOUTH BURLINGTON',
#   'VERMONT',
#   'UNITED STATES OF AMERICA',
#   '05403',
#   '802-383-1500',
#   '123',
#   370.0,
#   2001.0,
#   '541511',
#   'N',
#   'Kate A Keough',
#   '20 Kimball Avenue',
#   'Suite 303 North',
#   'South Burlington',
#   'VERMONT',
#   'UNITED STATES OF AMERICA',
#   '05403',
#   '802-383-1500*111 110',
#   'kate@itechus.com',
#   'Andrea M Wisner',
#   'iTech US, Inc.',
#   '727-365-2209',
#   109.0,
#   '20 Kimball Avenue',
#   'Suite 303 North',
#   'South Burlington',
#   'VERMONT',
#   'UNITED STATES OF AMERICA',
#   '05403',
#   'andrea@itechus.com'),
#  ('A-11199-93335',
#   'Denied',
#   '7/13/11',
#   '6/1/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'TRAMONTO, INC., DBA TRAMONTO  RESTAURANT',
#   '27 SAW MILL RIVER ROAD',
#   nan,
#   'HAWTHORNE',
#   'NEW YORK',
#   'UNITED STATES OF AMERICA',
#   '10532',
#   '(914) 347-8220',
#   nan,
#   25.0,
#   1995.0,
#   '722110',
#   'N',
#   'MICHAELA  SANTUCCI',
#   '27 SAW MILL RIVER ROAD',
#   nan,
#   'HAWTHORNE',
#   'NEW YORK',
#   'UNITED STATES OF AMERICA',
#   '10532',
#   '(914) 347-8220 ',
#   nan,
#   'JOSEPH A SENA, JR., ESQ.',
#   'LAW OFFICES OF JOSEPH A. SENA, JR.',
#   '(914) 287-0888',
#   nan,
#   '55 CHURCH STREET',
#   'SUITE 203',
#   'WHITE PLAINS',
#   'NEW YORK',
#   'UNITED STATES OF AMERICA',
#   '10601-1911',
#   'NYPERMS@JOSEPHSENALAW.COM'),
#  ('A-11209-96162',
#   'Certified',
#   '7/29/11',
#   '9/15/20',
#   'Y',
#   '4/30/01',
#   'P-04260-05078',
#   'N',
#   'ANCHOR CONSTRUCTION CORP.',
#   '2254 25TH PLACE, NE',
#   nan,
#   'WASHINGTON',
#   'DISTRICT OF COLUMBIA',
#   'UNITED STATES OF AMERICA',
#   '20018',
#   '202-269-6654',
#   nan,
#   175.0,
#   1985.0,
#   '236115',
#   'N',
#   'Florintino  Gregorio',
#   '2254 25TH PLACE, NE',
#   nan,
#   'WASHINGTON',
#   'DISTRICT OF COLUMBIA',
#   'UNITED STATES OF AMERICA',
#   '20018',
#   '202-269-6654 ',
#   'anchorconscorp@yahoo.com',
#   'Michael OR Emanuel  Mpras',
#   'Mpras Law Offices',
#   '703-642-9042',
#   nan,
#   '7361 McWhorter Place',
#   'Suite 311',
#   'Annandale',
#   'VIRGINIA',
#   'UNITED STATES OF AMERICA',
#   '22003',
#   'mmpras@msn.com'),
#  ('A-11227-99719',
#   'Certified-Expired',
#   '8/23/11',
#   '11/1/19',
#   'N',
#   nan,
#   nan,
#   'N',
#   'THE CHOATE ROSEMARY HALL FOUNDATION INCORPORATED',
#   '333 CHRISTIAN STREET',
#   nan,
#   'WALLINGFORD',
#   'CONNECTICUT',
#   'UNITED STATES OF AMERICA',
#   '06492',
#   '203.697.2000',
#   nan,
#   347.0,
#   1890.0,
#   '61111',
#   'N',
#   'Katherine L White',
#   '333 Christian Street',
#   nan,
#   'Wallingford',
#   'CONNECTICUT',
#   'UNITED STATES OF AMERICA',
#   '06492',
#   '203.697.2385 ',
#   'kwhite@choate.edu',
#   'Joan M Rowe',
#   'Wiggin and Dana LLP',
#   '2034984548',
#   nan,
#   '265 Church Street',
#   'P.O. Box 1832',
#   'New Haven',
#   'CONNECTICUT',
#   'UNITED STATES OF AMERICA',
#   '65081832',
#   'jrowe@wiggin.com'),
#  ('A-11236-01904',
#   'Denied',
#   '8/26/11',
#   '11/20/19',
#   'N',
#   nan,
#   nan,
#   'N',
#   'J  E WELDING INC.,',
#   '10930 EAST CLUBB ROAD',
#   nan,
#   'BEAUMONT',
#   'TEXAS',
#   'UNITED STATES OF AMERICA',
#   '77705',
#   '409-794-2311',
#   nan,
#   20.0,
#   2000.0,
#   '333992',
#   'N',
#   'Bruce W Deason',
#   '10930 East Clubb Road',
#   nan,
#   'Beaumont',
#   'TEXAS',
#   'UNITED STATES OF AMERICA',
#   '77720',
#   '409-794-2311 27',
#   'bruce@jewelding.com',
#   'Marva  Provo',
#   'Provo  Provo',
#   '409-835-0005',
#   nan,
#   '1815 McFaddin Street',
#   nan,
#   'Beaumont',
#   'TEXAS',
#   'UNITED STATES OF AMERICA',
#   '77701',
#   'mprovo@provolawfirm.com'),
#  ('A-11270-08495',
#   'Certified',
#   '10/10/11',
#   '4/30/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'P  E CONSTRUCTION, INC.',
#   '#188 BIRADAN SUMAK STREET',
#   'MACHANAO',
#   'DEDEDO',
#   'GUAM',
#   'UNITED STATES OF AMERICA',
#   '96929',
#   '671-632-3728',
#   nan,
#   38.0,
#   2006.0,
#   '236220',
#   'Y',
#   'ERNANITA T LAJATO',
#   'P.O. Box 25720 GMF',
#   nan,
#   'Barrigada',
#   'GUAM',
#   'UNITED STATES OF AMERICA',
#   '96921',
#   '671-632-3728 ',
#   'e.lajato@peconstructionguam.com',
#   'Melinda C Swavely',
#   'Dooley Roberts  Fowler LLP',
#   '671-646-1222',
#   nan,
#   'Suite 201 Orlean Pacific Plaza',
#   '865 South Marine Corp Drive',
#   'Tamuning',
#   'GUAM',
#   'UNITED STATES OF AMERICA',
#   '96913',
#   'swavely@guamlawoffice.com'),
#  ('A-11271-08498',
#   'Denied',
#   '9/28/11',
#   '6/17/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'HILL INTERNATIONAL, INC.',
#   '2005 MARKET STREET, 17TH FLOOR',
#   'ONE COMMERCE SQUARE',
#   'PHILADELPHIA',
#   'PENNSYLVANIA',
#   'UNITED STATES OF AMERICA',
#   '19103',
#   '215-309-7756',
#   nan,
#   2423.0,
#   1976.0,
#   '236220',
#   'N',
#   'Suzanne N Borger',
#   '303 Lippincott Centre',
#   nan,
#   'Marlton',
#   'NEW JERSEY',
#   'UNITED STATES OF AMERICA',
#   '08053',
#   '856-552-6715 ',
#   'suzanneborger@hillintl.com',
#   'Dev A Kayal',
#   'The WKC Law Group',
#   '3018304027',
#   nan,
#   '8720 Georgia Ave',
#   'Ste 1010',
#   'Silver Spring',
#   'MARYLAND',
#   'UNITED STATES OF AMERICA',
#   '20910',
#   'dkayal@webbkayal.us'),
#  ('A-11278-10169',
#   'Denied',
#   '10/5/11',
#   '12/27/19',
#   'N',
#   nan,
#   nan,
#   'N',
#   'TEXAS INSTRUMENTS INCORPORATED',
#   '12500 TI BLVD.',
#   nan,
#   'DALLAS',
#   'TEXAS',
#   'UNITED STATES OF AMERICA',
#   '75243',
#   '972-995-2011',
#   nan,
#   28400.0,
#   1930.0,
#   '33441',
#   'N',
#   'Theresa  Couch',
#   '13588 North Central Expressway, MS 3999',
#   nan,
#   'Dallas',
#   'TEXAS',
#   'UNITED STATES OF AMERICA',
#   '75243',
#   '972-995-2100 ',
#   't-couch@ti.com',
#   'Susan Z Steger',
#   'Fragomen, Del Rey, Bernsen  Loewy, LLP',
#   '9722336646',
#   nan,
#   '5080 Spectrum Drive',
#   'Suite 850W',
#   'Addison',
#   'TEXAS',
#   'UNITED STATES OF AMERICA',
#   '75001',
#   'ssteger@fragomen.com'),
#  ('A-11312-17052',
#   'Certified-Expired',
#   '12/5/11',
#   '11/1/19',
#   'N',
#   nan,
#   nan,
#   'N',
#   'PATNI AMERICAS, INC.',
#   'ONE BROADWAY',
#   '13TH FLOOR EMPLOYER NOW BRANDED AS IGATE AMERICAS, INC.',
#   'CAMBRIDGE',
#   'MASSACHUSETTS',
#   'UNITED STATES OF AMERICA',
#   '02142',
#   '617-914-8000',
#   nan,
#   2100.0,
#   1972.0,
#   '541511',
#   'N',
#   'Mithilesh  Sharma',
#   '100 Somerset Corporate Boulevard',
#   'Suite 5000',
#   'Bridgewater',
#   'NEW JERSEY',
#   'UNITED STATES OF AMERICA',
#   '08807',
#   '617-914-8000 8259',
#   'mithilesh.sharma@patni.com',
#   'Erik C Anderson',
#   'Goel  Anderson, LLC',
#   '703-796-9234',
#   nan,
#   '12100 Sunset Hills Road',
#   'Suite 301',
#   'Reston',
#   'VIRGINIA',
#   'UNITED STATES OF AMERICA',
#   '20190',
#   'erik.anderson@goellaw.com'),
#  ('A-11334-21103',
#   'Denied',
#   '11/30/11',
#   '8/26/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'PROGRAMMER RESOURCES INTERNATIONAL INC',
#   '174 CLARKSON RD.',
#   'SUITE 200',
#   'ELLISVILLE',
#   'MISSOURI',
#   'UNITED STATES OF AMERICA',
#   '63011',
#   '636-256-7172',
#   '101',
#   22.0,
#   1997.0,
#   '541513',
#   'N',
#   'Ajay  Patel',
#   '221 Clarkson Executive Park',
#   nan,
#   'Ellisville',
#   'MISSOURI',
#   'UNITED STATES OF AMERICA',
#   '63011',
#   '636-256-7172 ',
#   'ajay@prijbs.com',
#   'James R Gotcher',
#   'Global Immigration Partners, Inc.',
#   '(818) 914-6482',
#   nan,
#   '4505 Las Virgenes Road,',
#   'Suite 107',
#   'Calabasas',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '91302',
#   'glg@gotcherlaw.com'),
#  ('A-11355-26327',
#   'Certified',
#   '1/4/12',
#   '8/21/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'INTELLISOFT TECHNOLOGIES, INC.',
#   '1320 GREENWAY DRIVE',
#   'STE 460',
#   'IRVING',
#   'TEXAS',
#   'UNITED STATES OF AMERICA',
#   '75038',
#   '972-756-1212',
#   '103',
#   50.0,
#   1997.0,
#   '541511',
#   'N',
#   'Murty  Mulukutla',
#   '1320 Greenway Drive',
#   'STE 460',
#   'Irving',
#   'TEXAS',
#   'UNITED STATES OF AMERICA',
#   '75038',
#   '972-756-1212 103',
#   'intellisofthr@intellisofttech.com',
#   'Alan C Chen',
#   'Alan C. Chen, P.C.',
#   '9722355772',
#   nan,
#   '801 E. Campbell Rd. Suite 130',
#   nan,
#   'Richardson',
#   'TEXAS',
#   'UNITED STATES OF AMERICA',
#   '75081',
#   'acc@immigrationwork.net'),
#  ('A-11356-26337',
#   'Denied',
#   '12/22/11',
#   '11/20/19',
#   'N',
#   nan,
#   nan,
#   'N',
#   'SIMEIO SOLUTIONS, LLC',
#   '55 IVAN ALLEN JR., BLVD N.W',
#   'SUITE 350',
#   'ATLANTA',
#   'GEORGIA',
#   'UNITED STATES OF AMERICA',
#   '30308',
#   '770-282-4442',
#   nan,
#   29.0,
#   2007.0,
#   '541519',
#   'N',
#   'Jeanne  Maguire',
#   '5502 Lorelei Ave',
#   nan,
#   'Lakewood',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '90712',
#   '(281) 482-5069 ',
#   'jmaguire@simeiosolutions.com',
#   'Sandra  Gross',
#   'Siegel, Gross  Tou, PC',
#   '2484391595',
#   nan,
#   'P.O. Box 903',
#   nan,
#   'Troy',
#   'MICHIGAN',
#   'UNITED STATES OF AMERICA',
#   '48099',
#   'sandra@sgimmigration.com'),
#  ('A-12004-28527',
#   'Certified',
#   '1/4/12',
#   '7/16/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'TRANSAMERICA LIFE INSURANCE COMPANY',
#   '6400 C STREET SW 3845',
#   nan,
#   'CEDAR RAPIDS',
#   'IOWA',
#   'UNITED STATES OF AMERICA',
#   '52499',
#   '3193556760',
#   nan,
#   5519.0,
#   1961.0,
#   '5241',
#   'N',
#   'Vickie L Vlasek',
#   '4333 Edgewood Road NE',
#   nan,
#   'Cedar Rapids',
#   'IOWA',
#   'UNITED STATES OF AMERICA',
#   '52499',
#   '319/398-8519 ',
#   'vvlasek@aegonusa.com',
#   'David S Jones',
#   'Jackson Lewis, LLP',
#   '(901) 462-2607',
#   nan,
#   '999 Shady Grove Road, Suite 110',
#   'Suite 110',
#   'Memphis',
#   'TENNESSEE',
#   'UNITED STATES OF AMERICA',
#   '38120',
#   'jonesd@jacksonlewis.com'),
#  ('A-12009-29356',
#   'Certified-Expired',
#   '1/16/12',
#   '12/27/19',
#   'N',
#   nan,
#   nan,
#   'N',
#   'AP AVIATION MANAGEMENT CONSULTANT, LLC',
#   '833 SOUTH CHESTATEE',
#   nan,
#   'DAHLONEGA',
#   'GEORGIA',
#   'UNITED STATES OF AMERICA',
#   '30533',
#   '520-260-6973',
#   nan,
#   3.0,
#   1996.0,
#   '541690',
#   'N',
#   'Ashok  Patel',
#   '833 South Chestatee',
#   nan,
#   'Dahlonega',
#   'GEORGIA',
#   'UNITED STATES OF AMERICA',
#   '30533',
#   '520-260-6973 ',
#   'patel533@bellsouth.net',
#   'Lucy  Lu',
#   'Lucy Lu  Associates LLC',
#   '4043431766',
#   nan,
#   'Lucy Lu  Associates, LLC',
#   '3475 Lenox Road, Ste 730',
#   'Atlanta',
#   'GEORGIA',
#   'UNITED STATES OF AMERICA',
#   '30326',
#   'llu@lucylulaw.com'),
#  ('A-12009-29457',
#   'Certified-Expired',
#   '6/1/12',
#   '11/20/19',
#   'N',
#   nan,
#   nan,
#   'N',
#   'PROFICIENT BUSINESS SYSTEMS, INC.',
#   '2400 MEADOWBROOK PARKWAY',
#   nan,
#   'DULUTH',
#   'GEORGIA',
#   'UNITED STATES OF AMERICA',
#   '30096',
#   '847-380-4546',
#   nan,
#   190.0,
#   1994.0,
#   '541512',
#   'N',
#   'Baala  Ramalingam',
#   '175 E Hawthorn Parkway',
#   'Suite 405',
#   'Vernon Hills',
#   'ILLINOIS',
#   'UNITED STATES OF AMERICA',
#   '60061',
#   '847-247-8470 162',
#   'baala@probys.com',
#   'Krista L Carpenter',
#   'Piston  Carpenter P.C.',
#   '248-680-0600',
#   nan,
#   '4000 Livernois Road',
#   'Suite 110',
#   'Troy',
#   'MICHIGAN',
#   'UNITED STATES OF AMERICA',
#   '48098',
#   'greencard@piston.net'),
#  ('A-12034-36132',
#   'Denied',
#   '2/21/12',
#   '12/27/19',
#   'N',
#   nan,
#   nan,
#   'N',
#   'ACTUARIAL SYSTEMS CORPORATION',
#   '18321 VENTURA BOULEVARD',
#   'SUITE 660',
#   'TARZANA',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '91356',
#   '818-344-2084',
#   '110',
#   24.0,
#   1981.0,
#   '511210',
#   'N',
#   'Laurie  Joiner',
#   '18321 Ventura Boulevard',
#   'Suite 660',
#   'Tarzana',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '91356',
#   '818-344-2084 110',
#   'ljoiner@asc-net.com',
#   'Esther T Wong',
#   'Law Offices of Esther Tan Wong, APLC',
#   '6264578884',
#   nan,
#   '506 N. Garfield Ave., #250',
#   nan,
#   'Alhambra',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '91801',
#   'etanlaw@aol.com'),
#  ('A-12039-37181',
#   'Denied',
#   '2/8/12',
#   '11/6/19',
#   'N',
#   nan,
#   nan,
#   'N',
#   'FLUKE ELECTRONICS CORPORATION',
#   '6920 SEAWAY BLVD.',
#   'P. O.  BOX 9090',
#   'EVERETT',
#   'WASHINGTON',
#   'UNITED STATES OF AMERICA',
#   '98203',
#   '425-347-6100',
#   nan,
#   1218.0,
#   1992.0,
#   '238210',
#   'N',
#   'Carol  Kowalski',
#   '6920 Seaway Blvd.',
#   nan,
#   'Everett',
#   'WASHINGTON',
#   'UNITED STATES OF AMERICA',
#   '98203',
#   '(425) 446-6250 ',
#   'carol.kowalski@flukenetworks.com',
#   'Vickie F Li',
#   'Mikkelborg Broz Wells and Fryer',
#   '(206) 623-5890',
#   nan,
#   '1001 Fourth Avenue, Suite 3600',
#   nan,
#   'Seattle',
#   'WASHINGTON',
#   'UNITED STATES OF AMERICA',
#   '98154',
#   'vickieli@mikkelborg.com'),
#  ('A-12053-40771',
#   'Denied',
#   '2/23/12',
#   '5/24/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'INFOSYS INTERNATIONAL INC.',
#   '110 TERMINAL DR',
#   nan,
#   'PLAINVIEW',
#   'NEW YORK',
#   'UNITED STATES OF AMERICA',
#   '11803',
#   '516 - 576 9494',
#   '3300',
#   15.0,
#   1990.0,
#   '541512',
#   'Y',
#   'Raj  Mehta',
#   '110 Terminal Dr',
#   nan,
#   'Plainview',
#   'NEW YORK',
#   'UNITED STATES OF AMERICA',
#   '11803',
#   '516 - 576 9494 3300',
#   'Danny@InfosysInternational.Com',
#   'Dev B Viswanath',
#   'The Banad Law Offices, P.C.',
#   '2122647500',
#   nan,
#   '291 Broadway,',
#   'Ste 1005',
#   'New York',
#   'NEW YORK',
#   'UNITED STATES OF AMERICA',
#   '10007',
#   'Dev@banadlaw.com'),
#  ('A-12081-48348',
#   'Certified-Expired',
#   '5/19/12',
#   '11/5/19',
#   'N',
#   nan,
#   nan,
#   'N',
#   'HCL GLOBAL SYSTEMS INC',
#   '24543, INDOPLEX CIRCLE',
#   'STE # 220',
#   'FARMINGTON HILLS',
#   'MICHIGAN',
#   'UNITED STATES OF AMERICA',
#   '48335',
#   '248 473 0720',
#   nan,
#   569.0,
#   2005.0,
#   '541511',
#   'N',
#   'PRASAD  GADDE',
#   '24543, INDOPLEX CIRCLE',
#   'STE # 220',
#   'FARMINGTON HILLS',
#   'MICHIGAN',
#   'UNITED STATES OF AMERICA',
#   '48335',
#   '248 473 0720 ',
#   'HR@HCLGLOBAL.COM',
#   'Krista L Hurst',
#   'The Murray Law Group, P.C.',
#   '2485408019',
#   102.0,
#   '31780 Telegraph Road',
#   'Suite 200',
#   'Bingham Farms',
#   'MICHIGAN',
#   'UNITED STATES OF AMERICA',
#   '48025',
#   'khurst@murraylawpc.com'),
#  ('A-12107-54700',
#   'Denied',
#   '6/1/12',
#   '5/29/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'ITECH US INC.',
#   '20 KIMBALL AVENUE',
#   'SUITE 303 NORTH',
#   'SOUTH BURLINGTON',
#   'VERMONT',
#   'UNITED STATES OF AMERICA',
#   '05403',
#   '802-383-1500',
#   '123',
#   406.0,
#   2001.0,
#   '54151',
#   'N',
#   'Kate A Keough',
#   '20 Kimball Avenue',
#   'Suite 303 North',
#   'South Burlington',
#   'VERMONT',
#   'UNITED STATES OF AMERICA',
#   '05403',
#   '802-383-1500x111 110',
#   'kate@itechus.net',
#   'Sarah J Pelud',
#   'iTech US, Inc.',
#   '8023831500x129',
#   129.0,
#   '20 Kimball Ave',
#   'Suite 303 North',
#   'South Burlington',
#   'VERMONT',
#   'UNITED STATES OF AMERICA',
#   '05403',
#   'spelud@itechus.net'),
#  ('A-12107-54710',
#   'Denied',
#   '5/29/12',
#   '8/21/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'ITECH US INC.',
#   '20 KIMBALL AVENUE',
#   'SUITE 303 NORTH',
#   'SOUTH BURLINGTON',
#   'VERMONT',
#   'UNITED STATES OF AMERICA',
#   '05403',
#   '802-383-1500',
#   '123',
#   406.0,
#   2001.0,
#   '54151',
#   'N',
#   'Kate A Keough',
#   '20 Kimball Avenue',
#   'Suite 303 North',
#   'South Burlington',
#   'VERMONT',
#   'UNITED STATES OF AMERICA',
#   '05403',
#   '802-383-1500x111 110',
#   'kate@itechus.net',
#   'Sarah J Pelud',
#   'iTech US, Inc.',
#   '8023831500x129',
#   129.0,
#   '20 Kimball Ave',
#   'Suite 303 North',
#   'South Burlington',
#   'VERMONT',
#   'UNITED STATES OF AMERICA',
#   '05403',
#   'spelud@itechus.net'),
#  ('A-12123-59707',
#   'Denied',
#   '7/26/12',
#   '6/17/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'THE UNITED GROUP, INC. DBA UNITED TELECOM',
#   '5730 UPLANDER WAY',
#   'SUITE 104',
#   'CULVER CITY',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '90230',
#   '3107467406',
#   nan,
#   16.0,
#   1991.0,
#   '5179',
#   'N',
#   'Mel  Paydar',
#   '5730 UPLANDER WAY',
#   'SUITE 104',
#   'CULVER CITY',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '90230',
#   '3102891777',
#   'melp@unitedtelecom.com',
#   'Edward M Weisz',
#   'Law Offices of Edward M. Weisz',
#   '818-936-3560',
#   nan,
#   '6303 Owensmouth Ave,',
#   '10th Floor',
#   'Woodland Hills',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '91367',
#   'lawweisz@cs.com'),
#  ('A-12128-60578',
#   'Certified',
#   '5/3/12',
#   '9/1/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'WHITCRAFT, LLC.',
#   '76 COUNTY ROAD, P.O. BOX 128',
#   'P.O. BOX 128',
#   'EASTFORD',
#   'CONNECTICUT',
#   'UNITED STATES OF AMERICA',
#   '06242',
#   '(860) 630-4427',
#   nan,
#   293.0,
#   1960.0,
#   '336411',
#   'N',
#   'SANDRA L KAROSI',
#   '76 COUNTY RD.',
#   'P.O BOX 128',
#   'EASTFORD',
#   'CONNECTICUT',
#   'UNITED STATES OF AMERICA',
#   '06242',
#   '(860) 630-4427 ',
#   'SKAROSI@WHITCRAFT.COM',
#   'HOWARD L BAKER',
#   'WILENS  BAKER. P.C.',
#   '(212) 695-0060 X229',
#   nan,
#   '450 SEVENTH AVENUE, 12TH FLOOR',
#   nan,
#   'NEW YORK',
#   'NEW YORK',
#   'UNITED STATES OF AMERICA',
#   '10123',
#   'HBAKER@WILENSANDBAKER.COM'),
#  ('A-12136-63048',
#   'Certified',
#   '6/15/12',
#   '7/20/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'KPIT INFOSYSTEMS INC.',
#   'NOW KNOWN AS BIRLASOFT SOLUTIONS, INC.',
#   '399 THORNALL STREET, 8TH FLOOR',
#   'EDISON',
#   'NEW JERSEY',
#   'UNITED STATES OF AMERICA',
#   '08837',
#   '732-287-5000',
#   nan,
#   350.0,
#   1998.0,
#   '541511',
#   'N',
#   'Reena  Jencin',
#   '33 Wood Avenue South',
#   nan,
#   'Iselin',
#   'NEW JERSEY',
#   'UNITED STATES OF AMERICA',
#   '08830',
#   '732-321-0921 101',
#   'reena.jencin@kpitcummins.com',
#   'Ramesh  Gurnani',
#   'Gurnani  Gurnani',
#   '7324948900',
#   16.0,
#   '101 Lincoln Highway at Evergreen Rd.',
#   'Suite A',
#   'Edison',
#   'NEW JERSEY',
#   'UNITED STATES OF AMERICA',
#   '08820',
#   'ramesh@gurnani.com'),
#  ('A-12136-63057',
#   'Denied',
#   '5/15/12',
#   '7/29/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'LAURENS COUNTY SCHOOL DISTRICT 55',
#   '301 HILLCREST DR.',
#   nan,
#   'LAURENS',
#   'SOUTH CAROLINA',
#   'UNITED STATES OF AMERICA',
#   '29360',
#   '864-984-3568',
#   nan,
#   761.0,
#   1952.0,
#   '611110',
#   'N',
#   'Renee  Madden',
#   '1029 West Main Street',
#   nan,
#   'Laurens',
#   'SOUTH CAROLINA',
#   'UNITED STATES OF AMERICA',
#   '29360',
#   '864-984-3568 ',
#   'rmadden@laurens55.k12.sc.us',
#   '  ',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan),
#  ('A-12152-67695',
#   'Denied',
#   '6/15/12',
#   '8/24/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'MLOGICA INC',
#   '1835 W ORANGEWOOD AVE,',
#   'STE 200',
#   'ORANGE',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '92868',
#   '714-630-2500',
#   '4226',
#   7.0,
#   2004.0,
#   '541511',
#   'N',
#   'Amit  Okhandiar',
#   '2100 W Orangewood Ave,',
#   'STE 110',
#   'Orange',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '92868',
#   '714-630-2500 ',
#   'mL_Operation@mLogica.com',
#   'Bindi  Parikh',
#   'Parikh Law Offices',
#   '7029903292',
#   nan,
#   '701 N. Green Valley Pkwy',
#   'STE 200',
#   'Henderson',
#   'NEVADA',
#   'UNITED STATES OF AMERICA',
#   '89074',
#   'bindi@parikhlawoffices.com'),
#  ('A-12157-68887',
#   'Denied',
#   '6/26/12',
#   '4/29/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'IGATE GLOBAL SOLUTIONS, AN IGATE COMPANY',
#   '6528 KAISER DRIVE',
#   nan,
#   'FREMONT',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '94555',
#   '510-896-3003',
#   nan,
#   8000.0,
#   1986.0,
#   '541511',
#   'N',
#   'Nicole  Moser',
#   'Capgemini America, Inc.',
#   '333 W. Wacker Drive. STE 300',
#   'Chicago',
#   'ILLINOIS',
#   'UNITED STATES OF AMERICA',
#   '60606',
#   ' ',
#   'iasimmigration.nar@capgemini.com',
#   '  ',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan),
#  ('A-12158-69447',
#   'Certified',
#   '6/29/12',
#   '4/29/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'MISS HALLS SCHOOL',
#   '492 HOLMES ROAD',
#   nan,
#   'PITTSFIELD',
#   'MASSACHUSETTS',
#   'UNITED STATES OF AMERICA',
#   '01201',
#   '(413)395-7052',
#   nan,
#   96.0,
#   1924.0,
#   '611110',
#   'N',
#   'Risa L Maynard',
#   '492 Holmes Road',
#   nan,
#   'Pittsfield',
#   'MASSACHUSETTS',
#   'UNITED STATES OF AMERICA',
#   '01201',
#   '(413)395-7052 ',
#   'rmaynard@misshalls.org',
#   'Douglas  Hauer',
#   'MINTZ, LEVIN, COHN, FERRIS, GLOVSKY  POPEO',
#   '6173483044',
#   nan,
#   'One Financial Center',
#   '40th Floor',
#   'Boston',
#   'MASSACHUSETTS',
#   'UNITED STATES OF AMERICA',
#   '02111',
#   'dhauer@mintz.com'),
#  ('A-12163-70643',
#   'Certified-Expired',
#   '7/2/12',
#   '12/27/19',
#   'N',
#   nan,
#   nan,
#   'N',
#   'HSBC SECURITIES USA INC.',
#   '95 WASHINGTON STREET',
#   'ATRIUM 1NW',
#   'BUFFALO',
#   'NEW YORK',
#   'UNITED STATES OF AMERICA',
#   '14203',
#   '(716) 841-7508',
#   nan,
#   25000.0,
#   1865.0,
#   '523110',
#   'N',
#   'Pauline L Dennis',
#   '8 East 40th Street',
#   nan,
#   'New York',
#   'NEW YORK',
#   'UNITED STATES OF AMERICA',
#   '10016',
#   '(212) 525-4958 ',
#   'pauline.l.dennis@us.hsbc.com',
#   'Valarie H McPherson',
#   'Proskauer Rose LLP',
#   '(973) 274-6028',
#   nan,
#   'One Newark Center, 18th Floor',
#   nan,
#   'Newark',
#   'NEW JERSEY',
#   'UNITED STATES OF AMERICA',
#   '07102',
#   'vmcpherson@proskauer.com'),
#  ('A-12165-71289',
#   'Denied',
#   '6/26/12',
#   '11/20/19',
#   'N',
#   nan,
#   nan,
#   'N',
#   'IGATE GLOBAL SOLUTIONS, AN IGATE COMPANY',
#   '6528 KAISER DRIVE',
#   nan,
#   'FREMONT',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '94555',
#   '510-896-3003',
#   nan,
#   8000.0,
#   1986.0,
#   '541511',
#   'N',
#   'Nicole  Moser',
#   'Capgemini America, Inc.',
#   '333 W. Wacker Drive. STE 300',
#   'Chicago',
#   'ILLINOIS',
#   'UNITED STATES OF AMERICA',
#   '60606',
#   ' ',
#   'iasimmigration.nar@capgemini.com',
#   '  ',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan),
#  ('A-12170-73111',
#   'Denied',
#   '6/25/12',
#   '7/9/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'POWERTRANS FREIGHT SYSTEMS INC',
#   '2801 NW 74TH AVENUE',
#   'SUITE 226',
#   'MIAMI',
#   'FLORIDA',
#   'UNITED STATES OF AMERICA',
#   '33122',
#   '3059947424',
#   nan,
#   7.0,
#   1997.0,
#   '488510',
#   'N',
#   'Corey  Yoo',
#   '2801 NW 74TH AVENUE',
#   'SUITE 226',
#   'MIAMI',
#   'FLORIDA',
#   'UNITED STATES OF AMERICA',
#   '33122',
#   '3059947424',
#   'coreyoo@powertrans-mia.com',
#   'Kristin S Barbagallo',
#   'Law Offices of Sirota  Associates, PA',
#   '(305)373-1995',
#   nan,
#   '2999 NE 191st Street',
#   'Suite 900',
#   'Aventura',
#   'FLORIDA',
#   'UNITED STATES OF AMERICA',
#   '33180',
#   'ksirota@sirota.us'),
#  ('A-12171-73415',
#   'Denied',
#   '6/20/12',
#   '7/13/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'VICTORS PIZZA DEN 1',
#   '8406 OLD KEEN MILL ROAD',
#   nan,
#   'SPRINGFIELD',
#   'VIRGINIA',
#   'UNITED STATES OF AMERICA',
#   '22152',
#   '703-451-0313',
#   nan,
#   15.0,
#   1997.0,
#   '722110',
#   'N',
#   'John  Karousos',
#   '8406 OLD KEEN MILL ROAD',
#   nan,
#   'SPRINGFIELD',
#   'VIRGINIA',
#   'UNITED STATES OF AMERICA',
#   '22152',
#   '703-451-0313 ',
#   'vicspizza@yahoo.com',
#   'Michael OR Emanuel  Mpras',
#   'Mpras Law Offices',
#   '703-642-9042',
#   nan,
#   '7361 McWhorter Place',
#   'Suite 311',
#   'Annandale',
#   'VIRGINIA',
#   'UNITED STATES OF AMERICA',
#   '22003',
#   'mmpras@msn.com'),
#  ('A-12180-77202',
#   'Certified-Expired',
#   '6/28/12',
#   '11/20/19',
#   'N',
#   nan,
#   nan,
#   'N',
#   'FILOMENA LAKEVIEW',
#   '1738 COOPER STREET',
#   nan,
#   'DEPTFORD',
#   'NEW JERSEY',
#   'UNITED STATES OF AMERICA',
#   '08096',
#   '856-228-4235',
#   nan,
#   60.0,
#   2002.0,
#   '722110',
#   'N',
#   'MAURO  DIVENTURA',
#   '1738 COOPER STREET',
#   nan,
#   'DEPTFORD',
#   'NEW JERSEY',
#   'UNITED STATES OF AMERICA',
#   '08096',
#   '856-228-4235 ',
#   'chris@filomenalakeview.com',
#   'TAHIR  MELLA',
#   'LAW OFFICES OF TAHIR MELLA, P.C.',
#   '(215) 496-0690',
#   nan,
#   '1814 CALLOWHILL STREET',
#   'FIRST FLOOR',
#   'PHILADELPHIA',
#   'PENNSYLVANIA',
#   'UNITED STATES OF AMERICA',
#   '19130',
#   'bett.fabros@tahirmella.com'),
#  ('A-12181-78288',
#   'Certified',
#   '6/30/12',
#   '9/30/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'INFOTECH PRISM LLC',
#   '5865 NORTHPOINT PKWY',
#   'SUITE 200',
#   'ALPHARETTA',
#   'GEORGIA',
#   'UNITED STATES OF AMERICA',
#   '30022',
#   '770-573-0666',
#   '205',
#   27.0,
#   2006.0,
#   '541511',
#   'N',
#   'Rahman  Ziaur',
#   '2050 Marconi Dr',
#   'Suite 300',
#   'Alpharetta',
#   'GEORGIA',
#   'UNITED STATES OF AMERICA',
#   '30005',
#   '678-591-7755 ',
#   'zia@infotechprism.com',
#   'Vasanth  Vaidyanathan',
#   'Vasanth Vaidyanathan, Esq.',
#   '2137441567',
#   nan,
#   '100 East San Marcos Blvd',
#   'Suite 400',
#   'San Marcos',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '92069',
#   'vnathanlaw@gmail.com'),
#  ('A-12187-79265',
#   'Denied',
#   '7/5/12',
#   '11/20/19',
#   'N',
#   nan,
#   nan,
#   'N',
#   'PRELUDE SYSTEMS INC',
#   '5 CORPORATE PARK',
#   'SUITE # 140',
#   'IRVINE',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '92606',
#   '949-208-7126',
#   '488',
#   102.0,
#   1999.0,
#   '541511',
#   'N',
#   'Roy  Alexander',
#   '5 Corporate Park',
#   'Suite # 140',
#   'Irvine',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '92606',
#   '949-208-7126 488',
#   'immigration@preludesys.com',
#   'Jitesh  Malik',
#   'Malik  Popiel, P.C.',
#   '(212) 545-7770 x 201',
#   nan,
#   '145 WEST 45TH STREET, SUITE 402',
#   'Times Square',
#   'NEW YORK',
#   'NEW YORK',
#   'UNITED STATES OF AMERICA',
#   '10036',
#   'JMALIK@MALIKPOPIEL.COM'),
#  ('A-12194-81478',
#   'Certified-Expired',
#   '8/6/12',
#   '3/3/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'JK PARTNERS INC.',
#   'ONE HUNTINGTON QUAD, SUITE 2N05',
#   'SUITE 104',
#   'MELVILLE',
#   'NEW YORK NY',
#   'UNITED STATES OF AMERICA',
#   '11747',
#   '6317807127',
#   nan,
#   9.0,
#   2009.0,
#   '541990',
#   'N',
#   'Katrina  Finnegan',
#   '1600 Calebs Path Extension',
#   'Suite 104',
#   'Hauppauge',
#   'NEW YORK',
#   'UNITED STATES OF AMERICA',
#   '11788',
#   '631-482-3161 ',
#   'katrina@jkpartner.com',
#   'Mitchell C Zwaik',
#   'Mitchell C Zwaik  Associates PC',
#   '631-588-4040',
#   nan,
#   '5014 Express Drive South',
#   nan,
#   'Ronkonkoma',
#   'NEW YORK',
#   'UNITED STATES OF AMERICA',
#   '11779',
#   'mczwaik@zwaik.com'),
#  ('A-12194-81567',
#   'Denied',
#   '7/13/12',
#   '12/27/19',
#   'N',
#   nan,
#   nan,
#   'N',
#   'AXIS, INC.',
#   '3008 W. WILLOW KNOLLS DRIVE',
#   nan,
#   'PEORIA',
#   'ILLINOIS',
#   'UNITED STATES OF AMERICA',
#   '61614',
#   '309-691-3988',
#   '105',
#   259.0,
#   1987.0,
#   '541330',
#   'N',
#   'Angela  Loftus',
#   '3008 W. Willow Knolls Drive',
#   nan,
#   'Peoria',
#   'ILLINOIS',
#   'UNITED STATES OF AMERICA',
#   '61614',
#   '309-691-3988 105',
#   'aloftus@axis-inc.com',
#   'Erik C Anderson',
#   'Goel  Anderson, LLC',
#   '7037969234',
#   nan,
#   '12100 Sunset Hills Road, Third Floor',
#   nan,
#   'Reston',
#   'VIRGINIA',
#   'UNITED STATES OF AMERICA',
#   '20190',
#   'erik.anderson@goellaw.com'),
#  ('A-12200-83440',
#   'Certified',
#   '7/24/12',
#   '4/29/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'SYSTEM SOFT TECHNOLOGIES LLC',
#   '3000 BAYPORT DRIVE',
#   'SUITE#840',
#   'TAMPA',
#   'FLORIDA',
#   'UNITED STATES OF AMERICA',
#   '33607',
#   '727-723-0801',
#   '306',
#   380.0,
#   1999.0,
#   '541511',
#   'N',
#   'Stephanie  Dorsey',
#   '2600 McCormick Drive, Suite 230',
#   nan,
#   'Clearwater',
#   'FLORIDA',
#   'UNITED STATES OF AMERICA',
#   '33759',
#   '727-723-0801 320',
#   'stephanie.d@sstech.us',
#   'Rani M Emandi',
#   'Rani Emandi, Esquire, PLLC',
#   '2126867782',
#   nan,
#   '386 Park Ave South,  15th Floor',
#   nan,
#   'New York',
#   'NEW YORK',
#   'UNITED STATES OF AMERICA',
#   '10016',
#   'rani@emandilaw.com'),
#  ('A-12214-87522',
#   'Certified',
#   '8/8/12',
#   '7/16/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'DATASERV INC',
#   '1 TARA BLVD',
#   'SUITE 102',
#   'NASHUA',
#   'NEW HAMPSHIRE',
#   'UNITED STATES OF AMERICA',
#   '03062',
#   '603 821 4392',
#   nan,
#   46.0,
#   2005.0,
#   '541511',
#   'N',
#   'Anil  Potluri',
#   '71 Spit Brook Rd',
#   'Suite 102101',
#   'Nashua',
#   'NEW HAMPSHIRE',
#   'UNITED STATES OF AMERICA',
#   '03060',
#   '603 821 4392 ',
#   'kumar@dataservinc.com',
#   '  ',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan),
#  ('A-12216-88341',
#   'Denied',
#   '8/3/12',
#   '5/24/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'PYRAMID TECHNOLOGY SOLUTIONS, INC',
#   '9535 E. 59TH STREET',
#   'SUITE A',
#   'INDIANAPOLIS',
#   'INDIANA',
#   'UNITED STATES OF AMERICA',
#   '46216',
#   '317-280-9900',
#   '308',
#   151.0,
#   1998.0,
#   '541511',
#   'N',
#   'Dilip  Vadlamudi',
#   '9535 E. 59TH STREET',
#   'SUITE A',
#   'INDIANAPOLIS',
#   'INDIANA',
#   'UNITED STATES OF AMERICA',
#   '46216',
#   '317-280-9900 304',
#   'dilip1@pyramidinc.com',
#   'Navneet S Chugh',
#   'The Chugh Firm',
#   '5622291220',
#   nan,
#   '15925 Carmenita Road',
#   nan,
#   'Cerritos',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '90703',
#   'carmen@chugh.com'),
#  ('A-12223-90078',
#   'Denied',
#   '9/13/12',
#   '10/8/19',
#   'N',
#   nan,
#   nan,
#   'N',
#   'RAPID FILING SERVICES LLC',
#   '1841 BROADWAY',
#   'SUITE 902',
#   'NEW YORK',
#   'NEW YORK',
#   'UNITED STATES OF AMERICA',
#   '10023',
#   '212-664-1718',
#   '7001',
#   10.0,
#   2006.0,
#   '518210',
#   'N',
#   'Willem  Veldhuyzen',
#   '1841 Broadway',
#   'Suite 902',
#   'New York',
#   'NEW YORK',
#   'UNITED STATES OF AMERICA',
#   '10023',
#   '212-664-1718 7001',
#   'wv@rapidtax.com',
#   'Marc  Taylor',
#   'Marc Taylor Esq. P.C.',
#   '888-645-6272',
#   nan,
#   '366 Lewis Avenue, 1st Fl',
#   nan,
#   'Brooklyn',
#   'NEW YORK',
#   'UNITED STATES OF AMERICA',
#   '11233',
#   'perm@tnalaw.com'),
#  ('A-12228-91149',
#   'Certified',
#   '9/20/12',
#   '9/15/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'GOOGLE INC.',
#   '1600 AMPHITHEATRE PARKWAY',
#   nan,
#   'MOUNTAIN VIEW',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '94043',
#   '650-253-0000',
#   nan,
#   24400.0,
#   1998.0,
#   '51811',
#   'N',
#   'Lisa J Harrington',
#   '1600 Amphitheatre Parkway',
#   nan,
#   'Mountain View',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '94043',
#   '650-253-4901 ',
#   'visateam@google.com',
#   'Paul E Rynerson',
#   'Berry Applemen  Leiden LLP',
#   '2144427329',
#   nan,
#   '3232 McKinney Avenue',
#   'Suite 500',
#   'Dallas',
#   'TEXAS',
#   'UNITED STATES OF AMERICA',
#   '75240',
#   'prynerson@balglobal.com'),
#  ('A-12248-96266',
#   'Certified-Expired',
#   '9/4/12',
#   '12/27/19',
#   'N',
#   nan,
#   nan,
#   'N',
#   'HEXAWARE TECHNOLOGIES, INC.',
#   '101 WOOD AVENUE SOUTH',
#   'SUITE 600',
#   'ISELIN',
#   'NEW JERSEY',
#   'UNITED STATES OF AMERICA',
#   '08830',
#   '609 409 6950',
#   nan,
#   900.0,
#   1993.0,
#   '541511',
#   'N',
#   'Hariharan  Srinivasan',
#   '1095 Cranbury South River Road',
#   'Suite 10',
#   'Jamesburg',
#   'NEW JERSEY',
#   'UNITED STATES OF AMERICA',
#   '08831',
#   '609 409 6957 ',
#   'haris@hexaware.com',
#   'Michal D Terebelo',
#   'Fakhoury Law Group',
#   '248 643-4900',
#   nan,
#   '3290 West Big Beaver Rd.',
#   'Suite 510',
#   'Troy',
#   'MICHIGAN',
#   'UNITED STATES OF AMERICA',
#   '48084',
#   'michal@employmentimmigration.com'),
#  ('A-12255-97991',
#   'Denied',
#   '9/11/12',
#   '3/17/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'AJO UNIFIED SCHOOL DISTRICT #15',
#   '111 N. WELL ROAD',
#   nan,
#   'AJO',
#   'ARIZONA',
#   'UNITED STATES OF AMERICA',
#   '85321',
#   '520-387-5618',
#   nan,
#   75.0,
#   1896.0,
#   '611110',
#   'N',
#   'Robert F Dooley',
#   'P.O. Box 68,',
#   '111 N. Well Road',
#   'Ajo',
#   'ARIZONA',
#   'UNITED STATES OF AMERICA',
#   '85321',
#   '520-387-5618 ',
#   'angelina@tabletoptelephone.com',
#   'Richard T Frysinger',
#   'International Services Corporation',
#   '3015877044',
#   nan,
#   '1320 Fenwick Lane',
#   'Suite 202',
#   'Silver Spring',
#   'MARYLAND',
#   'UNITED STATES OF AMERICA',
#   '20910',
#   'rtfrysinger@gmail.com'),
#  ('A-12255-98162',
#   'Denied',
#   '9/24/12',
#   '9/15/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'SHIVKARAN, INC. , DBA  STOP  GO',
#   '17700, US HWY 441',
#   nan,
#   'MOUNT DORA',
#   'FLORIDA',
#   'UNITED STATES OF AMERICA',
#   '32757',
#   '(352)729-2744',
#   nan,
#   2.0,
#   2009.0,
#   '447110',
#   'N',
#   'KAMLESH  PATEL',
#   '17700, US HWY 441',
#   nan,
#   'Mount Dora',
#   'FLORIDA',
#   'UNITED STATES OF AMERICA',
#   '32757',
#   '(352)729-2744 ',
#   'shivkaraninc@yahoo.com',
#   'PHILIP M ZYNE',
#   'PHILIP M. ZYNE, P.A.',
#   '4078338951',
#   nan,
#   '1978 BRIDGEWATER DRIVE',
#   nan,
#   'HEATHROW',
#   'FLORIDA',
#   'UNITED STATES OF AMERICA',
#   '32746',
#   'pmzpa@aol.com'),
#  ('A-12256-98402',
#   'Denied',
#   '9/12/12',
#   '8/11/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'GSSR, INC',
#   '14900 BOGLE DRIVE',
#   'SUITE 100',
#   'CHANTILLY',
#   'VIRGINIA',
#   'UNITED STATES OF AMERICA',
#   '20151',
#   '703-880-2717',
#   nan,
#   45.0,
#   2000.0,
#   '541511',
#   'N',
#   'Maheshwar  Reddy',
#   '2875 TOWERVIEW RD',
#   'SUITE A1',
#   'HERNDON',
#   'VIRGINIA',
#   'UNITED STATES OF AMERICA',
#   '20171',
#   '703-880-2717 ',
#   'mahesh@gssr.com',
#   '  ',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan),
#  ('A-12268-01897',
#   'Certified-Expired',
#   '9/24/12',
#   '3/5/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'SYSNET TECHNOLOGY SOLUTIONS',
#   'ASTIR SERVICES LLC DBA SYSNET TECHNOLOGY SOLUTIONS',
#   '50 CRAGWOOD ROAD, SUITE 219',
#   'SOUTH PLAINFIELD',
#   'NEW JERSEY',
#   'UNITED STATES OF AMERICA',
#   '07080',
#   '9082798670',
#   '704',
#   80.0,
#   2010.0,
#   '541511',
#   'N',
#   'KISHORE  Ganji',
#   '50 cragwood road, suite 219',
#   nan,
#   'SOUTH PLAINFIELD',
#   'NEW JERSEY New Jersey',
#   'UNITED STATES OF AMERICA',
#   '07080',
#   '9082798670 703',
#   'kishoreg@sysnetts.com',
#   'Kavitha  Ramasami',
#   'Law Offices of Kavitha Ramasami',
#   '2125636600',
#   nan,
#   '450 Seventh Avenue, Suite 2600',
#   nan,
#   'New York',
#   'NEW YORK',
#   'UNITED STATES OF AMERICA',
#   '10123',
#   'kavitha@usimmigrationesq.com'),
#  ('A-12286-06838',
#   'Denied',
#   '10/12/12',
#   '5/24/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'NEBULA LLC',
#   '12801 WORLDGATE DRIVE, SUITE 500',
#   nan,
#   'HERNDON',
#   'VIRGINIA',
#   'UNITED STATES OF AMERICA',
#   '20170',
#   '703-863-1064',
#   nan,
#   3.0,
#   2006.0,
#   '541511',
#   'N',
#   'Kiran  Beebireddy',
#   '12020 Sunrise Valley Drive, Suite 100',
#   nan,
#   'Reston',
#   'VIRGINIA',
#   'UNITED STATES OF AMERICA',
#   '20191',
#   '703-863-1064 ',
#   'hr@nebulaitinc.com',
#   'Dustin W Dyer',
#   'Dyer Immigration Law Group, P.C.',
#   '8043777247',
#   nan,
#   'P.O. Box 5337',
#   nan,
#   'Glen Allen',
#   'VIRGINIA',
#   'UNITED STATES OF AMERICA',
#   '23058',
#   'dustin@dyerimmigration.com'),
#  ('A-12297-09839',
#   'Denied',
#   '12/27/12',
#   '4/29/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'SPECTRASEIS INC.',
#   '1600 STOUT STREET',
#   'SUITE 1600',
#   'DENVER',
#   'COLORADO',
#   'UNITED STATES OF AMERICA',
#   '80202',
#   '303-658-9171',
#   nan,
#   21.0,
#   2008.0,
#   '213112',
#   'N',
#   'David A Walker',
#   '1899 Wynkoop',
#   'Suite 350',
#   'Denver',
#   'COLORADO',
#   'UNITED STATES OF AMERICA',
#   '80202',
#   '281-798-1954 ',
#   'david.walker@spectraseis.com',
#   'Joan  Larson',
#   'Larson Law Firm',
#   '7136888472',
#   nan,
#   '2855 Mangum Rd.',
#   'Ste. 559',
#   'Houston',
#   'TEXAS',
#   'UNITED STATES OF AMERICA',
#   '77092',
#   'larsonlawfirm@att.net'),
#  ('A-12311-12917',
#   'Denied',
#   '12/10/12',
#   '9/1/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'UNIQUE SERVICES ASSOCIATES INC',
#   '1580 PINEHURST STREET',
#   nan,
#   'ORANGEBURG',
#   'SOUTH CAROLINA',
#   'UNITED STATES OF AMERICA',
#   '29115',
#   '803-614-7700',
#   nan,
#   3.0,
#   2007.0,
#   '611710',
#   'N',
#   'Navin  Patel',
#   '1580 Pinehurst Street',
#   nan,
#   'Orangeburg',
#   'SOUTH CAROLINA',
#   'UNITED STATES OF AMERICA',
#   '29115',
#   '803-614-7700 ',
#   'andy@uniqueservices.us.com',
#   'Marc  Taylor',
#   'Marc Taylor Esq. PC',
#   '8886456272',
#   nan,
#   '224 West 4th Street, Suite 200',
#   nan,
#   'New York',
#   'NEW YORK',
#   'UNITED STATES OF AMERICA',
#   '10014',
#   'info@usavisanow.com'),
#  ('A-12314-14018',
#   'Denied',
#   '11/9/12',
#   '12/27/19',
#   'N',
#   nan,
#   nan,
#   'N',
#   'MORNINGSTAR, INC.',
#   '22 W WASHINGTON ST',
#   nan,
#   'CHICAGO',
#   'ILLINOIS',
#   'UNITED STATES OF AMERICA',
#   '60602',
#   '312-696-6000',
#   nan,
#   1300.0,
#   1984.0,
#   '523930',
#   'N',
#   'Anna  Corona',
#   '22 W Washington St',
#   'MORNINGSTAR',
#   'Chicago',
#   'ILLINOIS',
#   'UNITED STATES OF AMERICA',
#   '60602',
#   '312-696-6000 ',
#   'anna.corona@morningstar.com',
#   'Timothy G Payne',
#   'Sidley Austin LLP',
#   '(312) 853-7000',
#   nan,
#   'One South Dearborn Street',
#   nan,
#   'Chicago',
#   'ILLINOIS',
#   'UNITED STATES OF AMERICA',
#   '60603',
#   'tpayne@sidley.com'),
#  ('A-12318-14422',
#   'Denied',
#   '11/13/12',
#   '9/17/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'EBOOKS WEB COM LLC',
#   '1388 BRIDGEWATER RD',
#   nan,
#   'BENSALEM',
#   'PENNSYLVANIA',
#   'UNITED STATES OF AMERICA',
#   '19020',
#   '888-215-0780',
#   nan,
#   12.0,
#   2009.0,
#   '45411',
#   'N',
#   'Saiful  Islam',
#   '1379 Bristol Rd',
#   nan,
#   'Churchville',
#   'PENNSYLVANIA',
#   'UNITED STATES OF AMERICA',
#   '18966',
#   '407-967-6840 ',
#   'saif92@aol.com',
#   'Richard D Steel',
#   'STEEL, DOEBLEY  GLASSMAN, P.C.',
#   '(215) 486-4175',
#   nan,
#   '1608 Walnut Street',
#   'Suite 1500',
#   'Philadelphia',
#   'PENNSYLVANIA',
#   'UNITED STATES OF AMERICA',
#   '19103-5410',
#   'rsteel@sdglawgroup.com'),
#  ('A-12320-15189',
#   'Denied',
#   '11/15/12',
#   '4/30/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'STEPHEN S. LEE  CO. LTD.',
#   '2241 WHITE OAK DR.',
#   nan,
#   'NORTHBROOK',
#   'ILLINOIS',
#   'UNITED STATES OF AMERICA',
#   '60062',
#   '847-291-8252',
#   nan,
#   6.0,
#   1989.0,
#   '541211',
#   'N',
#   'Stephen S Lee',
#   '2241 White Oak Dr.',
#   nan,
#   'Northbrook',
#   'ILLINOIS',
#   'UNITED STATES OF AMERICA',
#   '60062',
#   '847-291-8252 ',
#   'stephencpa@gmail.com',
#   'YoungEon  Kim',
#   'MIRAE LAW LLC',
#   '84729700094',
#   4.0,
#   '1701 Golf Road Suite 11106',
#   nan,
#   'Rolling Meadows',
#   'ILLINOIS',
#   'UNITED STATES OF AMERICA',
#   '60008',
#   'ryan@miraelaw.com'),
#  ('A-12320-15236',
#   'Denied',
#   '11/15/12',
#   '4/30/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'FLORIDA HOSPITAL ZEPHYRHILLS, INC.',
#   '7050 GALL BOULEVARD',
#   nan,
#   'ZEPHYRHILLS',
#   'FLORIDA',
#   'UNITED STATES OF AMERICA',
#   '33541',
#   '8137836119',
#   nan,
#   500.0,
#   1985.0,
#   '622110',
#   'N',
#   'Karla  Baer',
#   '7050 Gall Boulevard',
#   nan,
#   'Zephyrhills',
#   'FLORIDA',
#   'UNITED STATES OF AMERICA',
#   '33541',
#   '8137836119 1335',
#   'Karla.Baer2@ahss.org',
#   'Matthew D Westerman',
#   'Blalock Walters PA',
#   '9417480100',
#   nan,
#   '801 11th Street West',
#   nan,
#   'Bradenton',
#   'FLORIDA',
#   'UNITED STATES OF AMERICA',
#   '34205',
#   'mwesterman@blalockwalters.com'),
#  ('A-12332-17540',
#   'Denied',
#   '11/29/12',
#   '12/27/19',
#   'N',
#   nan,
#   nan,
#   'N',
#   'MSP INDUSTRIES CORPORATION',
#   '45 W. OAKWOOD',
#   nan,
#   'OXFORD',
#   'MICHIGAN',
#   'UNITED STATES OF AMERICA',
#   '48371',
#   '248-236-2211',
#   nan,
#   252.0,
#   1975.0,
#   '336350',
#   'Y',
#   'Barbara J LeRoy',
#   '45 W. Oakwood',
#   nan,
#   'Oxford',
#   'MICHIGAN',
#   'UNITED STATES OF AMERICA',
#   '48371',
#   '248-236-2211 ',
#   'barb.leroy@aam.com',
#   'Linda J Armstrong',
#   'Butzel Long',
#   '313 983-7476',
#   nan,
#   '150 West Jefferson',
#   'Suite 100',
#   'Detroit',
#   'MICHIGAN',
#   'UNITED STATES OF AMERICA',
#   '48226',
#   'armstrong@butzel.com'),
#  ('A-12345-21288',
#   'Denied',
#   '12/12/12',
#   '5/29/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'TANVI IT SOLUTIONS INC',
#   '4211, PLEASANT VALLEY ROAD',
#   'STE 230',
#   'CHANTILLY',
#   'VIRGINIA',
#   'UNITED STATES OF AMERICA',
#   '20151',
#   '7032606869',
#   '101',
#   18.0,
#   2008.0,
#   '541511',
#   'N',
#   'Nagoor V Inaganti',
#   '14125, Robert Paris Ct',
#   'Ste 101',
#   'Chantilly',
#   'VIRGINIA Fair Fax County',
#   'UNITED STATES OF AMERICA',
#   '20151',
#   '7032606869 101',
#   'vali@tanviit.com',
#   'Bhanu B Ilindra',
#   'BBI LAW GROUP, P.C.',
#   '7034967722',
#   nan,
#   'P.O. BOX 221',
#   nan,
#   'GREAT FALLS',
#   'VIRGINIA',
#   'UNITED STATES OF AMERICA',
#   '22066',
#   'Bhanu@IlindraLawGroup.com'),
#  ('A-12346-21874',
#   'Denied',
#   '12/12/12',
#   '5/29/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'BLUE CHIP MEDICAL PRODUCTS, INC',
#   '711 SUFFERN PLACE',
#   nan,
#   'SUFFERN',
#   'NEW YORK',
#   'UNITED STATES OF AMERICA',
#   '10901',
#   '845-369-7535',
#   '305',
#   18.0,
#   1996.0,
#   '337910',
#   'N',
#   'Carol  Wynne',
#   '711 SUFFERN PLACE',
#   nan,
#   'Suffern',
#   'NEW YORK',
#   'UNITED STATES OF AMERICA',
#   '10901',
#   '845-369-7535 305',
#   'cwynne@bluechipmedical.com',
#   'Rafael  Figueroa, Esq.',
#   'Rafael Figueroa, P.C.',
#   '2018610500',
#   nan,
#   '4808 Bergenline Ave',
#   'Suite 604',
#   'Union City',
#   'NEW JERSEY',
#   'UNITED STATES OF AMERICA',
#   '07087',
#   'rfpc@mindspring.com'),
#  ('A-12355-24694',
#   'Certified',
#   '2/26/13',
#   '7/17/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'OSI SYSTEMS, INC.',
#   '12525 CHADRON AVENUE',
#   nan,
#   'HAWTHORNE',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '90250',
#   '310-978-0516',
#   nan,
#   3366.0,
#   1987.0,
#   '33599',
#   'N',
#   'David  Scroggins',
#   '12525 Chadron Avenue',
#   nan,
#   'Hawthorne',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '90250',
#   '310-349-2424 ',
#   'dscroggins@osi-systems.com',
#   'Jeffrey  Ehrenpreis',
#   'Ralph Ehrenpreis, PLC',
#   '3105536600',
#   nan,
#   '1880 Century Park East',
#   'Suite 550',
#   'Los Angeles',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '90067',
#   'jeff@ralphehrenpreis.com'),
#  ('A-13007-28011',
#   'Certified-Expired',
#   '1/10/13',
#   '12/27/19',
# ...
#   '561720',
#   'N',
#   'Mary  Lukomske',
#   '127 Tanner Rd',
#   nan,
#   'Greenville',
#   'SOUTH CAROLINA',
#   'UNITED STATES OF AMERICA',
#   '29607',
#   '864-297-3748 ',
#   'mlukomske@ihservices.com',
#   'Vanessa  Olivar',
#   'Ogletree, Deakins, Nash, Smoak  Stewart, P.C.',
#   '2022630257',
#   nan,
#   '1909 K Street, N.W., Suite 1000',
#   nan,
#   'Washington',
#   'DISTRICT OF COLUMBIA',
#   'UNITED STATES OF AMERICA',
#   '20006',
#   'Vanessa.olivar@ogletree.com'),
#  ('A-18299-34083',
#   'Certified-Expired',
#   '8/2/19',
#   '10/7/19',
#   'N',
#   nan,
#   nan,
#   'N',
#   'AECOM TECHNICAL SERVICES, INC.',
#   '1999 AVENUE OF THE STARS',
#   '#2600',
#   'LOS ANGELES',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '90067',
#   '804-515-8514',
#   nan,
#   87000.0,
#   1970.0,
#   '541330',
#   'N',
#   'Kumar N Raman',
#   '4840 Cox Road',
#   nan,
#   'Glen Allen',
#   'VIRGINIA',
#   'UNITED STATES OF AMERICA',
#   '23060',
#   '804-515-8514 ',
#   'Kumar.Raman@aecom.com',
#   'Paige L Taylor',
#   'Fragomen, Del Rey, Bernsen  Loewy, LLP',
#   '9722336646',
#   nan,
#   '5080 Spectrum Drive',
#   'Suite 850W',
#   'Addison',
#   'TEXAS',
#   'UNITED STATES OF AMERICA',
#   '75001',
#   'ptaylor@fragomen.com'),
#  ('A-18299-34096',
#   'Certified-Expired',
#   '9/20/19',
#   '1/24/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'AECOM TECHNICAL SERVICES, INC.',
#   '1999 AVENUE OF THE STARS',
#   '#2600',
#   'LOS ANGELES',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '90067',
#   '804-515-8514',
#   nan,
#   87000.0,
#   1970.0,
#   '541330',
#   'N',
#   'Kumar N Raman',
#   '4840 Cox Road',
#   nan,
#   'Glen Allen',
#   'VIRGINIA',
#   'UNITED STATES OF AMERICA',
#   '23060',
#   '804-515-8514 ',
#   'Kumar.Raman@aecom.com',
#   'Paige L Taylor',
#   'Fragomen, Del Rey, Bernsen  Loewy, LLP',
#   '9722336646',
#   nan,
#   '5080 Spectrum Drive',
#   'Suite 850W',
#   'Addison',
#   'TEXAS',
#   'UNITED STATES OF AMERICA',
#   '75001',
#   'ptaylor@fragomen.com'),
#  ('A-18299-34111',
#   'Certified-Expired',
#   '9/6/19',
#   '12/9/19',
#   'N',
#   nan,
#   nan,
#   'N',
#   'CODE TECH INC',
#   '24155 DRAKE RD,',
#   'SUITE 205',
#   'FARMINGTON HILLS',
#   'MICHIGAN',
#   'UNITED STATES OF AMERICA',
#   '48335',
#   '2487578839',
#   nan,
#   44.0,
#   2012.0,
#   '541511',
#   'N',
#   'Nagini  Ellendula',
#   '24155 Drake Rd,',
#   'Suite#205',
#   'Farmington Hills',
#   'MICHIGAN',
#   'UNITED STATES OF AMERICA',
#   '48335',
#   '2487578839',
#   'nagini@codetech-inc.com',
#   'Camille  Joson',
#   'Reddy  Neumann, P.C.',
#   '713-457-5708',
#   nan,
#   'P.O.Box 421409',
#   nan,
#   'HOUSTON',
#   'TEXAS',
#   'UNITED STATES OF AMERICA',
#   '77242-1409',
#   'camille.joson@rnlawgroup.com'),
#  ('A-18299-34139',
#   'Denied',
#   '10/26/18',
#   '12/19/19',
#   'N',
#   nan,
#   nan,
#   'N',
#   'TECUMSEH POULTRY LLC',
#   '13151 DOVERS STREET',
#   nan,
#   'WAVERLY',
#   'NEBRASKA',
#   'UNITED STATES OF AMERICA',
#   '68462',
#   '4027861000',
#   nan,
#   564.0,
#   2000.0,
#   '311615',
#   'N',
#   'Trish  Reimers',
#   '13151 Dovers Street',
#   nan,
#   'Waverly',
#   'NEBRASKA',
#   'UNITED STATES OF AMERICA',
#   '68462',
#   '4027861000 1060',
#   'trishreimers@smartchicken.com',
#   'Jae Yoon  Jung',
#   'JA Immigration Inc',
#   '2133803100',
#   nan,
#   'P.O. Box 75839',
#   nan,
#   'Los Angeles',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '90075',
#   'permsc@jaandja.com'),
#  ('A-18299-34164',
#   'Certified',
#   '11/6/19',
#   '5/1/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'AECOM TECHNICAL SERVICES, INC.',
#   '1999 AVENUE OF THE STARS',
#   '#2600',
#   'LOS ANGELES',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '90067',
#   '804-515-8514',
#   nan,
#   87000.0,
#   1970.0,
#   '541330',
#   'N',
#   'Kumar N Raman',
#   '4840 Cox Road',
#   nan,
#   'Glen Allen',
#   'VIRGINIA',
#   'UNITED STATES OF AMERICA',
#   '23060',
#   '804-515-8514 ',
#   'Kumar.Raman@aecom.com',
#   'Paige L Taylor',
#   'Fragomen, Del Rey, Bernsen  Loewy, LLP',
#   '9722336646',
#   nan,
#   '5080 Spectrum Drive',
#   'Suite 850W',
#   'Addison',
#   'TEXAS',
#   'UNITED STATES OF AMERICA',
#   '75001',
#   'ptaylor@fragomen.com'),
#  ('A-18299-34177',
#   'Denied',
#   '10/29/18',
#   '12/19/19',
#   'N',
#   nan,
#   nan,
#   'N',
#   'TECUMSEH POULTRY LLC',
#   '13151 DOVERS STREET',
#   nan,
#   'WAVERLY',
#   'NEBRASKA',
#   'UNITED STATES OF AMERICA',
#   '68462',
#   '4027861000',
#   nan,
#   564.0,
#   2000.0,
#   '311615',
#   'N',
#   'Trish  Reimers',
#   '13151 Dovers Street',
#   nan,
#   'Waverly',
#   'NEBRASKA',
#   'UNITED STATES OF AMERICA',
#   '68462',
#   '4027861000 1060',
#   'trishreimers@smartchicken.com',
#   'Jae Yoon  Jung',
#   'JA Immigration Inc',
#   '2133803100',
#   nan,
#   'P.O. Box 75839',
#   nan,
#   'Los Angeles',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '90075',
#   'permsc@jaandja.com'),
#  ('A-18299-34180',
#   'Denied',
#   '11/13/19',
#   '4/15/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'SECURUS TECHNOLOGIES, INC',
#   '4000 INTERNATIONAL PARKWAY',
#   nan,
#   'CARROLLTON',
#   'TEXAS',
#   'UNITED STATES OF AMERICA',
#   '75007',
#   '9722770310',
#   nan,
#   1156.0,
#   1986.0,
#   '517919',
#   'N',
#   'Robbin  Smith',
#   '4000 International Parkway',
#   nan,
#   'Carrollton',
#   'TEXAS',
#   'UNITED STATES OF AMERICA',
#   '75007',
#   '(972) 277-0310 ',
#   'rtsmith@securustechnologies.com',
#   'John D Smart',
#   'Bell Nunnally  Martin LLP',
#   '214-740-1400',
#   nan,
#   '2323 Ross Ave.',
#   'Suite 1900',
#   'Dallas',
#   'TEXAS',
#   'UNITED STATES OF AMERICA',
#   '75201',
#   'jsmart@bellnunnally.com'),
#  ('A-18299-34211',
#   'Denied',
#   '11/5/18',
#   '2/24/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'NEW CLASSIC HOME  FURNISHINGS, INC.',
#   '7351 MCGUIRE AVE',
#   nan,
#   'FONTANA',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '92336',
#   '9094847676',
#   nan,
#   90.0,
#   2001.0,
#   '423210',
#   'N',
#   'Jean  Tong',
#   '7351 McGuire Ave',
#   nan,
#   'Fontana',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '92336',
#   '9099805066',
#   'jeantong2003@yahoo.com',
#   'BENJAMIN  Pan',
#   'New Rome Inc.',
#   '6265709647',
#   nan,
#   '505 N Garfield Ave',
#   nan,
#   'Alhambra',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '91801',
#   'newromeinc@gmail.com'),
#  ('A-18302-34325',
#   'Certified',
#   '11/5/19',
#   '4/3/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'BANK OF AMERICA',
#   '100 N. TRYON STREET',
#   nan,
#   'CHARLOTTE',
#   'NORTH CAROLINA',
#   'UNITED STATES OF AMERICA',
#   '28255',
#   '646-855-1847',
#   nan,
#   200000.0,
#   1904.0,
#   '522110',
#   'N',
#   'Rachel  Goldin',
#   '50 Rockefeller Plaza',
#   nan,
#   'New York',
#   'NEW YORK',
#   'UNITED STATES OF AMERICA',
#   '10020',
#   '646-855-1847 ',
#   'rachel.goldin@bankofamerica.com',
#   'Isha  Atassi',
#   'Fragomen, Del Rey, Bernsen  Loewy, LLP',
#   '2126888555',
#   nan,
#   '1400 Broadway',
#   nan,
#   'New York',
#   'NEW YORK',
#   'UNITED STATES OF AMERICA',
#   '10018',
#   'ktracey@fragomen.com'),
#  ('A-18302-34425',
#   'Denied',
#   '10/29/18',
#   '2/26/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'IH SERVICES, INC',
#   '127 TANNER RD',
#   nan,
#   'GREENVILLE',
#   'SOUTH CAROLINA',
#   'UNITED STATES OF AMERICA',
#   '29607',
#   '864-297-3748',
#   nan,
#   2500.0,
#   1968.0,
#   '561720',
#   'N',
#   'Mary  Lukomske',
#   '127 Tanner Rd',
#   nan,
#   'Greenville',
#   'SOUTH CAROLINA',
#   'UNITED STATES OF AMERICA',
#   '29607',
#   '864-297-3748 ',
#   'mlukomske@ihservices.com',
#   'Vanessa  Olivar',
#   'Ogletree, Deakins, Nash, Smoak  Stewart, P.C.',
#   '2022630257',
#   nan,
#   '1909 K Street, N.W., Suite 1000',
#   nan,
#   'Washington',
#   'DISTRICT OF COLUMBIA',
#   'UNITED STATES OF AMERICA',
#   '20006',
#   'vanessa.olivar@ogletreedeakins.com'),
#  ('A-18302-34447',
#   'Certified',
#   '6/14/19',
#   '4/3/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'FOULGERPRATT CONTRACTING LLC',
#   '12435 PARK POTOMAC AVENUE',
#   'SUITE 200',
#   'POTOMAC',
#   'MARYLAND',
#   'UNITED STATES OF AMERICA',
#   '20854',
#   '2404999600',
#   nan,
#   30.0,
#   1963.0,
#   '2381',
#   'N',
#   'Andrea  Hewitt',
#   '12435 Park Potomac Avenue',
#   'Suite 200',
#   'Potomac',
#   'MARYLAND',
#   'UNITED STATES OF AMERICA',
#   '20854',
#   '2404999680',
#   'ahewitt@foulgerpratt.com',
#   'Ronald D Richey',
#   'Law Office of Ronald D Richey',
#   '3017386909',
#   nan,
#   '230 N. Washington Street #300',
#   nan,
#   'Rockville',
#   'MARYLAND',
#   'UNITED STATES OF AMERICA',
#   '20850',
#   'info@immigrationlawrichey.com'),
#  ('A-18302-34452',
#   'Certified-Expired',
#   '6/14/19',
#   '3/27/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'FOULGERPRATT CONTRACTING LLC',
#   '12435 PARK POTOMAC AVENUE',
#   'SUITE 200',
#   'POTOMAC',
#   'MARYLAND',
#   'UNITED STATES OF AMERICA',
#   '20854',
#   '2404999600',
#   nan,
#   30.0,
#   1963.0,
#   '2381',
#   'N',
#   'Andrea  Hewitt',
#   '12435 Park Potomac Avenue',
#   'Suite 200',
#   'Potomac',
#   'MARYLAND',
#   'UNITED STATES OF AMERICA',
#   '20854',
#   '2404999680',
#   'ahewitt@foulgerpratt.com',
#   'Ronald D Richey',
#   'Law Office of Ronald D Richey',
#   '3017386909',
#   nan,
#   '230 N. Washington Street #300',
#   nan,
#   'Rockville',
#   'MARYLAND',
#   'UNITED STATES OF AMERICA',
#   '20850',
#   'info@immigrationlawrichey.com'),
#  ('A-18302-34473',
#   'Denied',
#   '10/30/18',
#   '10/10/19',
#   'N',
#   nan,
#   nan,
#   'N',
#   'ADAMS COLLISION CLINIC INC',
#   '5636 WEST ADAMS BLVD',
#   nan,
#   'LOS ANGELES',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '90016',
#   '323 936 3636',
#   nan,
#   6.0,
#   2015.0,
#   '811121',
#   'N',
#   'NADER  SABOROUH',
#   '5636 WEST ADAMS BLVD',
#   nan,
#   'LOS ANGELES',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '90016',
#   '323 936 3636 ',
#   'ADAMS90016@GMAIL.COM',
#   'KEN  BEHZADI',
#   'LAW OFFICES OF KEN K BEHZADI',
#   '310 441 9341',
#   nan,
#   '400 CORPORATE POINTE STE 300',
#   nan,
#   'CULVER CITY',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '90230',
#   'KENBEHZADI@GMAIL.COM'),
#  ('A-18302-34476',
#   'Certified',
#   '12/17/19',
#   '5/5/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'ENERSYS DELAWARE INC.',
#   '2366 BERNVILLE ROAD',
#   nan,
#   'READING',
#   'PENNSYLVANIA',
#   'UNITED STATES OF AMERICA',
#   '19605',
#   '6102081991',
#   nan,
#   11220.0,
#   1998.0,
#   '33591',
#   'N',
#   'Ted  Fries',
#   '2366 Bernville Road',
#   nan,
#   'Reading',
#   'PENNSYLVANIA',
#   'UNITED STATES OF AMERICA',
#   '19605',
#   '610-208-1622 ',
#   'ted.fries@enersys.com',
#   'Alexander R Castrodale',
#   'Cohen  Grigsby, P.C.',
#   '4122974712',
#   nan,
#   '625 Liberty Avenue, Floor 5',
#   nan,
#   'Pittsburgh',
#   'PENNSYLVANIA',
#   'UNITED STATES OF AMERICA',
#   '15222',
#   'acastrodale@cohenlaw.com'),
#  ('A-18302-34487',
#   'Certified',
#   '11/19/19',
#   '4/10/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'AECOM TECHNICAL SERVICES, INC.',
#   '1999 AVENUE OF THE STARS',
#   '#2600',
#   'LOS ANGELES',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '90067',
#   '804-515-8514',
#   nan,
#   87000.0,
#   1970.0,
#   '541330',
#   'N',
#   'Kumar N Raman',
#   '4840 Cox Road',
#   nan,
#   'Glen Allen',
#   'VIRGINIA',
#   'UNITED STATES OF AMERICA',
#   '23060',
#   '804-515-8514 ',
#   'Kumar.Raman@aecom.com',
#   'Paige L Taylor',
#   'Fragomen, Del Rey, Bernsen  Loewy, LLP',
#   '9722336646',
#   nan,
#   '5080 Spectrum Drive',
#   'Suite 850W',
#   'Addison',
#   'TEXAS',
#   'UNITED STATES OF AMERICA',
#   '75001',
#   'ptayloriv@fragomen.com'),
#  ('A-18302-34586',
#   'Denied',
#   '10/29/18',
#   '12/19/19',
#   'N',
#   nan,
#   nan,
#   'N',
#   'TECUMSEH POULTRY LLC',
#   '13151 DOVERS STREET',
#   nan,
#   'WAVERLY',
#   'NEBRASKA',
#   'UNITED STATES OF AMERICA',
#   '68462',
#   '4027861000',
#   nan,
#   564.0,
#   2000.0,
#   '311615',
#   'N',
#   'Trish  Reimers',
#   '13151 Dovers Street',
#   nan,
#   'Waverly',
#   'NEBRASKA',
#   'UNITED STATES OF AMERICA',
#   '68462',
#   '4027861000 1060',
#   'trishreimers@smartchicken.com',
#   'Jae Yoon  Jung',
#   'JA Immigration Inc',
#   '2133803100',
#   nan,
#   'P.O. Box 75839',
#   nan,
#   'Los Angeles',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '90075',
#   'permsc@jaandja.com'),
#  ('A-18302-34602',
#   'Certified-Expired',
#   '6/3/19',
#   '3/19/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'ORION HEALTH, INC.',
#   '7350 EAST EVANS ROAD',
#   'SUITE B100',
#   'SCOTTSDALE',
#   'ARIZONA',
#   'UNITED STATES OF AMERICA',
#   '85260',
#   '480-201-7987',
#   nan,
#   190.0,
#   2005.0,
#   '541511',
#   'N',
#   'DEBORAH  WAHL',
#   '7350 EAST EVANS ROAD',
#   'SUITE C100',
#   'SCOTTSDALE',
#   'ARIZONA',
#   'UNITED STATES OF AMERICA',
#   '85260',
#   '480-201-7987 ',
#   'deb.wahl@orionhealth.com',
#   'Lorna A De Bono',
#   'Haight Law Group, PC',
#   '310-910-9880',
#   nan,
#   '4551 Glencoe Avenue, Suite 320',
#   nan,
#   'Marina del Rey',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '90292',
#   'perm@haightlaw.com'),
#  ('A-18302-34663',
#   'Certified-Expired',
#   '9/10/19',
#   '12/20/19',
#   'N',
#   nan,
#   nan,
#   'N',
#   'COMPUSOFT INTEGRATED SOLUTIONS, INC.',
#   '31500 W. 13 MILE ROAD',
#   'STE # 200',
#   'FARMINGTON HILLS',
#   'MICHIGAN',
#   'UNITED STATES OF AMERICA',
#   '48334',
#   '2485389494',
#   '102',
#   60.0,
#   1997.0,
#   '541511',
#   'N',
#   'Pratap K Koganti',
#   '31500 W. 13 Mile Road',
#   'Ste # 200',
#   'Farmington Hills',
#   'MICHIGAN',
#   'UNITED STATES OF AMERICA',
#   '48334',
#   '2485389494 102',
#   'pkoganti@compusoft-is.com',
#   'Jeffrey A Weisberg',
#   'Law Offices of Amarnath Gowda, P.C.',
#   '248-932-0630',
#   nan,
#   '32871 Middlebelt Road, Suite 100',
#   nan,
#   'Farmington Hills',
#   'MICHIGAN',
#   'UNITED STATES OF AMERICA',
#   '48334',
#   'Marchel@gowda.com'),
#  ('A-18302-34704',
#   'Certified-Expired',
#   '2/15/19',
#   '10/11/19',
#   'N',
#   nan,
#   nan,
#   'N',
#   'SILICUS TECHNOLOGIES, LLC',
#   '2700 POST OAK BLVD STE 1625',
#   nan,
#   'HOUSTON',
#   'TEXAS',
#   'UNITED STATES OF AMERICA',
#   '77056',
#   '7133537400',
#   nan,
#   52.0,
#   2014.0,
#   '541511',
#   'N',
#   'Sumant  Ahuja',
#   '2700 Post Oak Blvd Ste 1625',
#   nan,
#   'Houston',
#   'TEXAS',
#   'UNITED STATES OF AMERICA',
#   '77056',
#   '7133537411',
#   'sumant.ahuja@silicus.com',
#   'Krystal  Alanis',
#   'Reddy  Neumann, P.C.',
#   '7134575703',
#   nan,
#   'P. O. Box 421409',
#   nan,
#   'Houston',
#   'TEXAS',
#   'UNITED STATES OF AMERICA',
#   '77242-1409',
#   'krystal@rnlawgroup.com'),
#  ('A-18302-34708',
#   'Denied',
#   '10/31/18',
#   '12/18/19',
#   'N',
#   nan,
#   nan,
#   'N',
#   'TECUMSEH POULTRY LLC',
#   '13151 DOVERS STREET',
#   nan,
#   'WAVERLY',
#   'NEBRASKA',
#   'UNITED STATES OF AMERICA',
#   '68462',
#   '4027861000',
#   nan,
#   564.0,
#   2000.0,
#   '311615',
#   'N',
#   'Trish  Reimers',
#   '13151 Dovers Street',
#   nan,
#   'Waverly',
#   'NEBRASKA',
#   'UNITED STATES OF AMERICA',
#   '68462',
#   '4027861000 1060',
#   'trishreimers@smartchicken.com',
#   'Jae Yoon  Jung',
#   'JA Immigration Inc',
#   '2133803100',
#   nan,
#   'P.O. Box 75839',
#   nan,
#   'Los Angeles',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '90075',
#   'permsc@jaandja.com'),
#  ('A-18302-34713',
#   'Certified-Expired',
#   '10/29/18',
#   '10/31/19',
#   'N',
#   nan,
#   nan,
#   'N',
#   'ABBYLAND FOODS, INC',
#   '502 EAST LINDEN STREET',
#   nan,
#   'ABBOTSFORD',
#   'WISCONSIN',
#   'UNITED STATES OF AMERICA',
#   '54405',
#   '715-316-0361',
#   '7704',
#   1150.0,
#   1977.0,
#   '311611',
#   'N',
#   'Ericka  Rossani',
#   '4404 Rib Mountain Drive #288',
#   nan,
#   'Wausau',
#   'WISCONSIN',
#   'UNITED STATES OF AMERICA',
#   '54401',
#   '715-316-0361 7704',
#   'flc@abbyland.com',
#   'Julian  Chung',
#   'Global Labor Solutions, LLC',
#   '8887109201',
#   nan,
#   'P.O. Box 3275',
#   nan,
#   'Duluth',
#   'GEORGIA',
#   'UNITED STATES OF AMERICA',
#   '30096',
#   'contact@steadyworkers.com'),
#  ('A-18302-34723',
#   'Certified-Expired',
#   '1/30/19',
#   '10/15/19',
#   'N',
#   nan,
#   nan,
#   'N',
#   'MIDWEST AUTO LUBE  REPAIR LLC',
#   '1700 N ROCKWELL AVE',
#   nan,
#   'BETHANY',
#   'OKLAHOMA',
#   'UNITED STATES OF AMERICA',
#   '73008',
#   '4054956664',
#   nan,
#   12.0,
#   2013.0,
#   '8111',
#   'N',
#   'Allen  Odetallah',
#   '1700 N ROCKWELL AVE',
#   nan,
#   'BETHANY',
#   'OKLAHOMA',
#   'UNITED STATES OF AMERICA',
#   '73008',
#   '4054956664',
#   'rockwellautojobs@gmail.com',
#   'Roger W Nayar',
#   'Farzaneh Law Firm',
#   '405-528-2222',
#   nan,
#   '1025 SW 4th Street',
#   'Suite 201',
#   'Moore',
#   'OKLAHOMA',
#   'UNITED STATES OF AMERICA',
#   '73160',
#   'rrn@farzaneh.com'),
#  ('A-18302-34742',
#   'Certified-Expired',
#   '9/18/19',
#   '1/24/20',
#   'N',
#   nan,
#   nan,
#   'N',
#   'AECOM',
#   '1999 AVENUE OF THE STARS',
#   '#2600',
#   'LOS ANGELES',
#   'CALIFORNIA',
#   'UNITED STATES OF AMERICA',
#   '90067',
#   '804-515-8514',
#   nan,
#   87000.0,
#   1990.0,
#   '541330',
#   'N',
#   'Kumar  Raman',
#   '4840 Cox Road',
#   nan,
#   'Glen Allen',
#   'VIRGINIA',
#   'UNITED STATES OF AMERICA',
#   '23060',
#   '804-515-8514 ',
#   'kumar.raman@aecom.com',
#   'Paige L Taylor',
#   'Fragomen, Del Rey, Bernsen  Loewy LLP',
#   '9722336646',
#   nan,
#   '5080 Spectrum Drive',
#   'Suite 850W',
#   'Addison',
#   'TEXAS',
#   'UNITED STATES OF AMERICA',
#   '75001',
#   'ptaylor@fragomen.com'),
#  ...]

# %%
# ****************************************************************** this does not work
# *********** mogrify no longer exists

def do_execute_batch(conn, df, table, page_size=150):
    tups = [tuple(x) for x in df.to_numpy()]

    cols = ','.join(list(df.columns))
    
    sql = "insert into {} VALUES {}".format(table, ', '.join(['%s'] * len(cols))),'id'
    cursor = db.cursor()
    try:
        extras.execute_values(cursor, sql, tups, page_size)
        conn.commit()
        print('Data inserted')
    except psycopg2.DatabaseError as e:
        print(e)
        cursor.close()
